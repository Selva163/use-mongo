# %%
import pymongo as pm
from pymongo import MongoClient
from bson import Code
# client = MongoClient('localhost', 27017)
client = MongoClient('mongodb://localhost:27017/')
stockDB = client.stock
companyDB = client.companyData
stockCol = stockDB.stocks
companyCol = companyDB.companies

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We'll be using pymongo to query mongodb, however the js commands has also been included for each operation as docstring.
# If no docstring, please do yourself

# %%
#lets see the structure of each collection

"""
db.stocks.findOne()
"""
stockCol.find_one()
# Out:
# {'_id': ObjectId('4d094f58c96767d7a0099d49'),
#  'exchange': 'NASDAQ',
#  'stock_symbol': 'AACC',
#  'date': '2008-03-07',
#  'open': 8.4,
#  'high': 8.75,
#  'low': 8.08,
#  'close': 8.55,
#  'volume': 275800,
#  'adj close': 8.55}

# %%
"""
db.companies.findOne()
"""
companyCol.find_one()
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297d8b'),
#  'name': 'AdventNet',
#  'permalink': 'abc3',
#  'crunchbase_url': 'http://www.crunchbase.com/company/adventnet',
#  'homepage_url': 'http://adventnet.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'manageengine',
#  'category_code': 'enterprise',
#  'number_of_employees': 600,
#  'founded_year': 1996,
#  'deadpooled_year': 2,
#  'tag_list': '',
#  'alias_list': 'Zoho ManageEngine ',
#  'email_address': 'pr@adventnet.com',
#  'phone_number': '925-924-9500',
#  'description': 'Server Management Software',
#  'created_at': datetime.datetime(2007, 5, 25, 19, 24, 22),
#  'updated_at': 'Wed Oct 31 18:26:09 UTC 2012',
#  'overview': '<p>AdventNet is now <a href="/company/zoho-manageengine" title="Zoho ManageEngine" rel="nofollow">Zoho ManageEngine</a>.</p>\n\n<p>Founded in 1996, AdventNet has served a diverse range of enterprise IT, networking and telecom customers.</p>\n\n<p>AdventNet supplies server and network management software.</p>',
#  'image': {'available_sizes': [[[150, 55],
#     'assets/images/resized/0001/9732/19732v1-max-150x150.png'],
#    [[150, 55], 'assets/images/resized/0001/9732/19732v1-max-250x250.png'],
#    [[150, 55], 'assets/images/resized/0001/9732/19732v1-max-450x450.png']]},
#  'products': [],
#  'relationships': [{'is_past': True,
#    'title': 'CEO and Co-Founder',
#    'person': {'first_name': 'Sridhar',
#     'last_name': 'Vembu',
#     'permalink': 'sridhar-vembu'}},
#   {'is_past': True,
#    'title': 'VP of Business Dev',
#    'person': {'first_name': 'Neil',
#     'last_name': 'Butani',
#     'permalink': 'neil-butani'}},
#   {'is_past': True,
#    'title': 'Usabiliy Engineer',
#    'person': {'first_name': 'Bharath',
#     'last_name': 'Balasubramanian',
#     'permalink': 'bharath-balasibramanian'}},
#   {'is_past': True,
#    'title': 'Director of Engineering',
#    'person': {'first_name': 'Rajendran',
#     'last_name': 'Dandapani',
#     'permalink': 'rajendran-dandapani'}},
#   {'is_past': True,
#    'title': 'Market Analyst',
#    'person': {'first_name': 'Aravind',
#     'last_name': 'Natarajan',
#     'permalink': 'aravind-natarajan'}},
#   {'is_past': True,
#    'title': 'Director of Product Management',
#    'person': {'first_name': 'Hyther',
#     'last_name': 'Nizam',
#     'permalink': 'hyther-nizam'}},
#   {'is_past': True,
#    'title': 'Western Regional OEM Sales Manager',
#    'person': {'first_name': 'Ian',
#     'last_name': 'Wenig',
#     'permalink': 'ian-wenig'}}],
#  'competitions': [],
#  'providerships': [{'title': 'DHFH',
#    'is_past': True,
#    'provider': {'name': 'A Small Orange', 'permalink': 'a-small-orange'}}],
#  'total_money_raised': '$0',
#  'funding_rounds': [],
#  'investments': [],
#  'acquisition': None,
#  'acquisitions': [],
#  'offices': [{'description': 'Headquarters',
#    'address1': '4900 Hopyard Rd.',
#    'address2': 'Suite 310',
#    'zip_code': '94588',
#    'city': 'Pleasanton',
#    'state_code': 'CA',
#    'country_code': 'USA',
#    'latitude': 37.692934,
#    'longitude': -121.904945}],
#  'milestones': [],
#  'video_embeds': [],
#  'screenshots': [{'available_sizes': [[[150, 94],
#      'assets/images/resized/0004/3400/43400v1-max-150x150.png'],
#     [[250, 156], 'assets/images/resized/0004/3400/43400v1-max-250x250.png'],
#     [[450, 282], 'assets/images/resized/0004/3400/43400v1-max-450x450.png']],
#    'attribution': None}],
#  'external_links': [],
#  'partners': []}

# %%
# %%time
#get distinct keys in each collection
#we can use map reduce in mongodb. the 'map' function operates on all doc that matches optional 'query' condition we can pass.
#reduce will receive a key and a single value or list of values on which we can do aggregation. 
#more at  https://docs.mongodb.com/manual/core/map-reduce/
#Note : "myresults" is actually a collection which stores the results of reduce which will be used for other functions like finalize

map_ = Code("function() { for (var key in this) { emit(key, null); } }")
reduce_ = Code("function(key, stuff) { return null; }")
result = stockCol.map_reduce(map_, reduce_, "myresults")
print(result)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stock'), 'myresults')
# Wall time: 3min 30s

# %%
# %%time

#aggregation pipeline works similar to mapreduce but it gives a nice way to construct our pipeline in a easy understandable way.

"""
db.stocks.aggregate([{ "$project": {
    "data": { "$objectToArray": "$$ROOT" }
  }},
  { "$project": { "data": "$data.k" }},
  { "$unwind": "$data" },
  { "$group": {
    "_id": null,
    "keys": { "$addToSet": "$data" }}}]).pretty()

"""

distinctKeyPipeline = [
  { "$project": {
    "data": { "$objectToArray": "$$ROOT" }
  }},
  { "$project": { "data": "$data.k" }},
  { "$unwind": "$data" },
  { "$group": {
    "_id": None,
    "keys": { "$addToSet": "$data" }}}]

distinctKeys = [doc for doc in stockCol.aggregate(distinctKeyPipeline)]
distinctKeys
# Out:
# Wall time: 42.4 s
# [{'_id': None,
#   'keys': ['high',
#    'close',
#    'open',
#    '_id',
#    'low',
#    'date',
#    'adj close',
#    'stock_symbol',
#    'volume',
#    'exchange']}]

# %%
#Lets see how many docs has the field 'products' in companies collection
companyCol.find({"products" : {"$exists": True}}).count()
# Out:
# 18801

# %%
#all the docs has the field but only 5519 has some value
"""
we can use [], '', None (pymongo) or null in (mongo cli) to check how many docs has actual values
"""
companyCol.find({"products" : {"$exists": True, "$ne":[]}}).count()
# Out:
# 5519

# %%
#how many docs in each collection
"""
db.stocks.count()
"""
print("Stock collection: ", stockCol.count())
print("Companies collection: ", companyCol.count())
# Out:
# Stock collection:  4308303
# Companies collection:  18801

# %%
#how many distinct stock_symbol we have
"""
db.stocks.distinct('stock_symbol').length
"""
len(stockCol.distinct('stock_symbol'))
# Out:
# 1618

# %%
#how many distinct titles in companies collection. we can access the nested elements easily in mongodb
"""
db.companies.distinct('relationships.title').length
"""
len(companyCol.distinct('relationships.title'))
# Out:
# 30205

# %%
#we have more than 30K values. just quickly test that we can access distinct elements from list.
"""
db.companies.distinct('relationships.is_past').length
"""
companyCol.distinct('relationships.is_past')
# Out:
# [None, False, True]

# %%
#nested doc can be accessed even further
"""
db.companies.distinct('relationships.person.first_name').length
"""
len(companyCol.distinct('relationships.person.first_name'))
# Out:
# 9218

# %%
#find how many companies has "CEO and Co-Founder" role
"""
db.companies.find({"relationships.title": "CEO and Co-Founder"}).count()
"""

len(list(companyCol.find({"relationships.title": "CEO and Co-Founder"})))
# Out:
# 55

# %%
#above command produces too much of strings, lets print or "project" just the company names that has the role.
#in the below if we set name : 0 , then all keys exept name. and we can't mix 0 and 1's here. _id will be default and explicitly mention 0
"""
db.companies.find({"relationships.title": "CEO and Co-Founder"}, {"name": 1})
"""

list(companyCol.find({"relationships.title": "CEO and Co-Founder"}, {"name" : 1, "_id":0}))
# Out:
# [{'name': 'AdventNet'},
#  {'name': 'Prosper'},
#  {'name': 'Mashery'},
#  {'name': 'Meebo'},
#  {'name': 'introNetworks'},
#  {'name': 'ZYB'},
#  {'name': 'Pluck'},
#  {'name': 'Lastminute'},
#  {'name': 'Dopplr'},
#  {'name': 'Mobovivo'},
#  {'name': 'JackBe'},
#  {'name': 'BitGravity'},
#  {'name': 'Eurekster'},
#  {'name': 'Pelago'},
#  {'name': 'Omniture'},
#  {'name': 'jellyfish'},
#  {'name': 'myfirstpaycheck'},
#  {'name': 'XO Group'},
#  {'name': 'Skydeck'},
#  {'name': 'Omnisio'},
#  {'name': 'AnchorFree'},
#  {'name': 'iovation'},
#  {'name': 'Friend2Friend'},
#  {'name': 'deviantART'},
#  {'name': 'IndieFlix'},
#  {'name': 'Musicbank'},
#  {'name': 'Limbo'},
#  {'name': 'Forticom'},
#  {'name': 'Vitrium Systems'},
#  {'name': 'Shapeways'},
#  {'name': 'LivingSocial'},
#  {'name': 'iloho'},
#  {'name': 'BizFilings'},
#  {'name': 'Livebookings'},
#  {'name': 'Interspire'},
#  {'name': 'Fitbit'},
#  {'name': 'VideoSurf'},
#  {'name': 'Gamelet'},
#  {'name': 'Interspire'},
#  {'name': 'Fitbit'},
#  {'name': 'VideoSurf'},
#  {'name': 'Gamelet'},
#  {'name': 'Nameprotect'},
#  {'name': 'LiveStub'},
#  {'name': 'deltatre'},
#  {'name': 'Navision'},
#  {'name': 'Asyncast Corporation'},
#  {'name': 'OpSource'},
#  {'name': 'TileStack'},
#  {'name': 'Perkler'},
#  {'name': 'Tobii Technology'},
#  {'name': 'MyLikes'},
#  {'name': 'UnboundID'},
#  {'name': 'InvestorLoft'},
#  {'name': 'LinkoTec'}]

# %%
list(companyCol.find({"name": "PBworks"}))[0]
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297e03'),
#  'name': 'PBworks',
#  'permalink': 'pbworks',
#  'crunchbase_url': 'http://www.crunchbase.com/company/pbworks',
#  'homepage_url': 'http://www.pbworks.com',
#  'blog_url': 'http://blog.pbworks.com/',
#  'blog_feed_url': 'http://blog.pbworks.com/feed/',
#  'twitter_username': 'PBworks',
#  'category_code': 'enterprise',
#  'number_of_employees': 25,
#  'founded_year': 2005,
#  'founded_month': 6,
#  'founded_day': 1,
#  'deadpooled_year': None,
#  'deadpooled_month': None,
#  'deadpooled_day': None,
#  'deadpooled_url': None,
#  'tag_list': 'wiki, social, collaboration, productivity, enterprise, cloud',
#  'alias_list': '',
#  'email_address': 'sales@pbworks.com',
#  'phone_number': '415-963-4369',
#  'description': 'Hosted Collaboration Provider',
#  'created_at': 'Sat Jul 14 09:55:02 UTC 2007',
#  'updated_at': 'Fri Oct 25 12:12:18 UTC 2013',
#  'overview': '<p>With over a million communities using PBworks to collaborate publicly and privately, PBworks is the largest business and educational hosted collaboration solution in the world. PBworks serves teams at over a third of the Fortune 500, is home to three presidential campaigns, the United Nations, The Financial Times and Harvard University. Like Salesforce, PBworks is a paid subscription service, with no advertising. </p>\n\n<p>PBworks hosts collaborative wikis that can be used by anyone and for anything, featuring a setup that takes less time than making a peanut butter sandwich and easy, point-and-click editing. Users can insert video and photos, chat rooms, voice chat, community calendars and all other sorts of media which can then be rearranged or added to by other users given access privilege. Competitors include <a href="http://crunchbase.com/company/microsoft" title="Microsoft Sharepoint">Microsoft Sharepoint</a>, <a href="http://crunchbase.com/company/atlassian" title="Atlassian Confluence">Atlassian Confluence</a>, and <a href="http://crunchbase.com/company/socialtext" title="Socialtext">Socialtext</a>.</p>',
#  'image': {'available_sizes': [[[150, 22],
#     'assets/images/resized/0002/4612/24612v5-max-150x150.png'],
#    [[151, 23], 'assets/images/resized/0002/4612/24612v5-max-250x250.png'],
#    [[151, 23], 'assets/images/resized/0002/4612/24612v5-max-450x450.png']],
#   'attribution': None},
#  'products': [{'name': 'PBworks', 'permalink': 'pbwiki'}],
#  'relationships': [{'is_past': False,
#    'title': 'CEO',
#    'person': {'first_name': 'Jim',
#     'last_name': 'Groff',
#     'permalink': 'jim-groff'}},
#   {'is_past': False,
#    'title': 'Founder & Chairman',
#    'person': {'first_name': 'David E.',
#     'last_name': 'Weekly',
#     'permalink': 'david-weekly'}},
#   {'is_past': False,
#    'title': 'VP/Marketing',
#    'person': {'first_name': 'Chris',
#     'last_name': 'Yeh',
#     'permalink': 'chris-yeh'}},
#   {'is_past': False,
#    'title': 'Board',
#    'person': {'first_name': 'Konstantin',
#     'last_name': 'Othmer',
#     'permalink': 'konstantin-othmer'}},
#   {'is_past': False,
#    'title': 'Board',
#    'person': {'first_name': 'Jon',
#     'last_name': 'Feiber',
#     'permalink': 'jon-feiber'}},
#   {'is_past': False,
#    'title': 'Board Member',
#    'person': {'first_name': 'Mehdi',
#     'last_name': 'Maghsoodnia',
#     'permalink': 'mehdi-maghsoodnia'}},
#   {'is_past': False,
#    'title': 'Creative Director',
#    'person': {'first_name': 'Dann',
#     'last_name': 'Ledwick',
#     'permalink': 'dann-ledwick'}},
#   {'is_past': True,
#    'title': 'CTO',
#    'person': {'first_name': 'Nathan',
#     'last_name': 'Schmidt',
#     'permalink': 'nathan-schmidt'}},
#   {'is_past': True,
#    'title': 'VP Marketing',
#    'person': {'first_name': 'Ramit',
#     'last_name': 'Sethi',
#     'permalink': 'ramit-sethi'}},
#   {'is_past': True,
#    'title': 'Board',
#    'person': {'first_name': 'Peter',
#     'last_name': 'Weck',
#     'permalink': 'peter-weck'}},
#   {'is_past': True,
#    'title': 'Software Engineer',
#    'person': {'first_name': 'Jim',
#     'last_name': 'Puls',
#     'permalink': 'jim-puls'}},
#   {'is_past': True,
#    'title': 'Head of Operations & IT',
#    'person': {'first_name': 'Ryan',
#     'last_name': 'Park',
#     'permalink': 'ryan-park'}},
#   {'is_past': True,
#    'title': 'Marketing intern',
#    'person': {'first_name': 'Andrea',
#     'last_name': 'Barrica',
#     'permalink': 'andrea-barrica'}},
#   {'is_past': True,
#    'title': 'Director of Engineering',
#    'person': {'first_name': 'Brian',
#     'last_name': 'Klug',
#     'permalink': 'brian-klug'}},
#   {'is_past': True,
#    'title': 'Controller',
#    'person': {'first_name': 'Emily',
#     'last_name': 'Marcroft',
#     'permalink': 'emily-marcroft'}},
#   {'is_past': True,
#    'title': 'Accounting Manager, Board Secretary',
#    'person': {'first_name': 'Emily',
#     'last_name': 'Marcroft',
#     'permalink': 'emily-marcroft'}},
#   {'is_past': True,
#    'title': 'Software Engineer',
#    'person': {'first_name': 'Max',
#     'last_name': 'Hodak',
#     'permalink': 'max-hodak'}}],
#  'competitions': [{'competitor': {'name': 'Socialtext',
#     'permalink': 'socialtext'}},
#   {'competitor': {'name': 'Atlassian', 'permalink': 'atlassian'}},
#   {'competitor': {'name': 'Box', 'permalink': 'box'}},
#   {'competitor': {'name': 'Jive Software', 'permalink': 'jive-software'}},
#   {'competitor': {'name': 'Huddle', 'permalink': 'huddle'}},
#   {'competitor': {'name': 'Wiggio', 'permalink': 'wiggio'}},
#   {'competitor': {'name': 'Ezenia MxM Secure',
#     'permalink': 'ezenia-mxm-secure'}},
#   {'competitor': {'name': 'Hall', 'permalink': 'hall-com'}}],
#  'providerships': [],
#  'total_money_raised': '$10.5M',
#  'funding_rounds': [{'id': 143,
#    'round_code': 'angel',
#    'source_url': 'http://www.paidcontent.org/entry/wiki-hosting-firm-pbwiki-gets-angel-money/',
#    'source_description': '',
#    'raised_amount': 350000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2006,
#    'funded_month': 9,
#    'funded_day': 11,
#    'investments': [{'company': None,
#      'financial_org': None,
#      'person': {'first_name': 'Ron',
#       'last_name': 'Conway',
#       'permalink': 'ron-conway'}},
#     {'company': None,
#      'financial_org': None,
#      'person': {'first_name': 'Chris',
#       'last_name': 'Yeh',
#       'permalink': 'chris-yeh'}},
#     {'company': None,
#      'financial_org': {'name': 'Seraph Group', 'permalink': 'seraph-group'},
#      'person': None}]},
#   {'id': 144,
#    'round_code': 'unattributed',
#    'source_url': 'http://www.paidcontent.org/entry/419-pbwiki-secures-21m-in-funding',
#    'source_description': '',
#    'raised_amount': 2100000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2007,
#    'funded_month': 2,
#    'funded_day': 1,
#    'investments': [{'company': None,
#      'financial_org': {'name': 'Mohr Davidow Ventures',
#       'permalink': 'mohr-davidow-ventures'},
#      'person': None},
#     {'company': None,
#      'financial_org': None,
#      'person': {'first_name': 'Ron',
#       'last_name': 'Conway',
#       'permalink': 'ron-conway'}},
#     {'company': None,
#      'financial_org': None,
#      'person': {'first_name': 'Chris',
#       'last_name': 'Yeh',
#       'permalink': 'chris-yeh'}}]},
#   {'id': 23116,
#    'round_code': 'unattributed',
#    'source_url': 'http://sec.gov/Archives/edgar/vprr/08/9999999997-08-036315',
#    'source_description': 'SEC',
#    'raised_amount': 3500000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2008,
#    'funded_month': 8,
#    'funded_day': 6,
#    'investments': []},
#   {'id': 23117,
#    'round_code': 'unattributed',
#    'source_url': 'http://sec.gov/Archives/edgar/data/1393483/000139348309000003/xslFormDX01/primary_doc.xml',
#    'source_description': 'SEC',
#    'raised_amount': 650000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2009,
#    'funded_month': 11,
#    'funded_day': 20,
#    'investments': []},
#   {'id': 41021,
#    'round_code': 'unattributed',
#    'source_url': 'http://www.sec.gov/Archives/edgar/data/1393483/000139348313000003/xslFormDX01/primary_doc.xml',
#    'source_description': 'SEC',
#    'raised_amount': 3908252,
#    'raised_currency_code': 'USD',
#    'funded_year': 2013,
#    'funded_month': 4,
#    'funded_day': 1,
#    'investments': [{'company': None,
#      'financial_org': {'name': 'Seraph Group', 'permalink': 'seraph-group'},
#      'person': None}]}],
#  'investments': [],
#  'acquisition': None,
#  'acquisitions': [],
#  'offices': [{'description': 'Headquarters',
#    'address1': '1825 S. Grant St.',
#    'address2': 'Suite 850',
#    'zip_code': '94402',
#    'city': 'San Mateo',
#    'state_code': 'CA',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  'milestones': [],
#  'ipo': None,
#  'video_embeds': [{'embed_code': '<iframe title="YouTube video player" width="480" height="300" src="http://www.youtube.com/embed/RszV4MnCCz0?rel=0&amp;hd=1" frameborder="0" allowfullscreen></iframe>',
#    'description': '<p>Learn How To Use PBworks</p>'}],
#  'screenshots': [{'available_sizes': [[[150, 112],
#      'assets/images/resized/0012/5711/125711v2-max-150x150.jpg'],
#     [[250, 187], 'assets/images/resized/0012/5711/125711v2-max-250x250.jpg'],
#     [[450, 337], 'assets/images/resized/0012/5711/125711v2-max-450x450.jpg']],
#    'attribution': None}],
#  'external_links': [],
#  'partners': []}

# %%
#finding companies that has either of the roles "Director of Engineering", "CEO and Co-Founder"

len(list(companyCol.find({"relationships.title": {"$in" : ["Director of Engineering", "CEO and Co-Founder"]}}, {"name": 1})))
# Out:
# 196

# %%
#finding companies that has the role "Director of Engineering" and founding year is > 2005

len(list(companyCol.find({"$and" : [ {"relationships.title" : "Director of Engineering" }, 
                                    {"founded_year" : {"$gt" : 2005}}]}, {"name": 1})))
# Out:
# 46

# %%
#same as above, without using "$and"

len(list(companyCol.find({"relationships.title": "Director of Engineering","founded_year" : {"$gt" : 2005}}, {"name": 1})))
# Out:
# 46

# %%
#however if we're using "and" on the same field, then we have to use "$and", else the last condition will replace all other conditions

len(list(companyCol.find({"$and" : [ {"relationships.title" : "Director of Engineering" }, 
                                    {"relationships.title" :"CEO and Co-Founder"}]}, {"name": 1})))
# Out:
# 2

# %%
len(list(companyCol.find({"relationships.title": "Director of Engineering","relationships.title": "CEO and Co-Founder"}, {"name": 1})))
# Out:
# 55

# %%
#following is the same as above

len(list(companyCol.find({"relationships.title": "CEO and Co-Founder"}, {"name": 1})))
# Out:
# 55

# %%
#we can use "$all" as well instead of "$and"

len(list(companyCol.find({"relationships.title" : {"$all" : ["Director of Engineering","CEO and Co-Founder"]}}, {"name": 1})))
# Out:
# 2

# %%
#lets find the companies that has "Sales Director" role and is_past = False

list(companyCol.find({"relationships.title": "Sales Director","relationships.is_past" : False}, {"name": 1,
                                                                                                              "relationships.title" : 1,
                                                                                                             "relationships.is_past":1}))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8e'),
#   'name': 'Facebook',
#   'relationships': [{'is_past': False,
#     'title': 'Founder and CEO, Board Of Directors'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False, 'title': 'COO'},
#    {'is_past': False, 'title': 'Vice- President and General Counsel'},
#    {'is_past': False, 'title': 'VP of Engineering & Product'},
#    {'is_past': False, 'title': 'VP, Global Advertising Sales'},
#    {'is_past': False,
#     'title': 'Vice President Advertising and Global Operations'},
#    {'is_past': False, 'title': 'VP, EMEA'},
#    {'is_past': False, 'title': 'VP, Advertising'},
#    {'is_past': False, 'title': 'VP Human Resources, Recruiting'},
#    {'is_past': False, 'title': 'VP of Engineering'},
#    {'is_past': False, 'title': 'VP Product'},
#    {'is_past': False, 'title': 'VP Engineering & Products'},
#    {'is_past': False, 'title': 'VP of Partnerships and Platform Marketing'},
#    {'is_past': False, 'title': 'Vice President, Engineering'},
#    {'is_past': False,
#     'title': 'VP of Global Communications, Marketing and Public Policy'},
#    {'is_past': False, 'title': 'Board of Directors/Investor'},
#    {'is_past': False, 'title': 'Board Director'},
#    {'is_past': False, 'title': 'Director of Monetization'},
#    {'is_past': False, 'title': 'Head of Security'},
#    {'is_past': False, 'title': 'Marketing Director'},
#    {'is_past': False, 'title': 'Director of Public Policy'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Business Development Manager'},
#    {'is_past': False, 'title': 'Platform Product Marketing'},
#    {'is_past': False, 'title': 'Manager, Site Reliability Engineering'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Engineering Director'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Engineer'},
#    {'is_past': False,
#     'title': 'Manager of Product Marketing, Facebook Credits'},
#    {'is_past': False, 'title': 'Head of platform partnerships'},
#    {'is_past': False, 'title': 'Corporate Development'},
#    {'is_past': False, 'title': 'Director, Product Management'},
#    {'is_past': False, 'title': 'Monetization Analytics'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Strategic Partner Manager, Games'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Photos Product Manger'},
#    {'is_past': False, 'title': 'Director of Engineering'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Communication Designer'},
#    {'is_past': False, 'title': 'Product Designer'},
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'Manager of Strategic Partnerships'},
#    {'is_past': False, 'title': 'Strategic Partner Development - Commerce'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'International Growth'},
#    {'is_past': False, 'title': 'Troublemaker'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Head of Analytics'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Facebook'},
#    {'is_past': False, 'title': 'Head of Vertical Measurement'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Growth'},
#    {'is_past': False, 'title': 'Director of Platform Operations'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Engineering Director / Site Director'},
#    {'is_past': False, 'title': 'Sustainability Guru'},
#    {'is_past': False, 'title': 'Investor'},
#    {'is_past': False, 'title': 'Product Designer'},
#    {'is_past': False, 'title': 'Director, Artificial Intelligence Lab'},
#    {'is_past': False, 'title': 'Head of Intl BD & Strategy'},
#    {'is_past': False, 'title': 'Board Of Directors'},
#    {'is_past': False, 'title': 'Platform Program Manager'},
#    {'is_past': False, 'title': 'Product Marketing Manager'},
#    {'is_past': False, 'title': 'Product Designer'},
#    {'is_past': False, 'title': 'Board Observer/Investor'},
#    {'is_past': False, 'title': 'Board member'},
#    {'is_past': False, 'title': 'Engineering Manager'},
#    {'is_past': False, 'title': 'Director, Mobile'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Hacker'},
#    {'is_past': False, 'title': 'Head of Mobile Products'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Engineer'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Corporate Development'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Director, Identity Product Group'},
#    {'is_past': False, 'title': 'Product Designer'},
#    {'is_past': False, 'title': 'Developer Relations'},
#    {'is_past': False, 'title': 'Sales and Advertising'},
#    {'is_past': False, 'title': 'Mobile Software Engineer'},
#    {'is_past': False, 'title': 'Data scientist'},
#    {'is_past': False, 'title': 'Product Manager, Mobile'},
#    {'is_past': False, 'title': 'Product and Mobile Operations'},
#    {'is_past': False, 'title': 'Media Solutions'},
#    {'is_past': False, 'title': 'Product Designer'},
#    {'is_past': False, 'title': 'Mobile Eng Manager'},
#    {'is_past': False, 'title': 'Engineering Intern'},
#    {'is_past': False, 'title': 'Member of Board of Directors'},
#    {'is_past': False, 'title': 'Engineering Director'},
#    {'is_past': False, 'title': 'Product Manager, Location & Events'},
#    {'is_past': False, 'title': 'Engineering Manager'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Group Director, Global Marketing Solutions'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Product Manager'},
#    {'is_past': False, 'title': 'Investor'},
#    {'is_past': False, 'title': 'ads'},
#    {'is_past': False, 'title': 'Head of Global Business Operations'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'User Interface Engineer'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Director, University Recruiting'},
#    {'is_past': False, 'title': 'Account Manager'},
#    {'is_past': False, 'title': 'Director of Product Management'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Deputy Counsel'},
#    {'is_past': False, 'title': 'Investor'},
#    {'is_past': False, 'title': 'Head of Partner Engineering'},
#    {'is_past': False, 'title': 'Manager, Product Design'},
#    {'is_past': False, 'title': 'Head of Korea'},
#    {'is_past': True, 'title': 'Co-Founder'},
#    {'is_past': True, 'title': 'Co-Founder'},
#    {'is_past': True, 'title': 'Co-founder'},
#    {'is_past': True, 'title': 'Co-Founder'},
#    {'is_past': True, 'title': 'Chief Malware Researcher'},
#    {'is_past': True, 'title': 'CTO'},
#    {'is_past': True, 'title': 'CFO'},
#    {'is_past': True,
#     'title': 'Chief Privacy Officer / Head of Global Public Policy'},
#    {'is_past': True, 'title': 'CFO'},
#    {'is_past': True, 'title': 'Chief Revenue Officer, VP of Operations'},
#    {'is_past': True, 'title': 'VP of Sales, West Region'},
#    {'is_past': True, 'title': 'VP Product Engineering'},
#    {'is_past': True, 'title': 'VP, General Counsel'},
#    {'is_past': True, 'title': 'VP Global Sales'},
#    {'is_past': True, 'title': 'VP Product'},
#    {'is_past': True, 'title': 'VP Sales/Consultant'},
#    {'is_past': True, 'title': 'VP of Technical Operations'},
#    {'is_past': True, 'title': 'VP of Product Management'},
#    {'is_past': True,
#     'title': 'VP of Growth, Mobile and International, VP of Platform and Product Marketing'},
#    {'is_past': True, 'title': 'Senior Platform Manager'},
#    {'is_past': True, 'title': 'Engineering Lead'},
#    {'is_past': True, 'title': 'Observer to Board of Directors'},
#    {'is_past': True, 'title': 'General Counsel'},
#    {'is_past': True, 'title': 'Product Development Manager'},
#    {'is_past': True, 'title': 'Creative Director'},
#    {'is_past': True, 'title': 'Developer Relations Manager'},
#    {'is_past': True, 'title': 'Director, User Experience and Design'},
#    {'is_past': True, 'title': 'Marketing'},
#    {'is_past': True, 'title': 'Platform Program Manager'},
#    {'is_past': True, 'title': 'Open Source and Web Standards Program Manager'},
#    {'is_past': True, 'title': 'Designer'},
#    {'is_past': True, 'title': 'Independent Contractor'},
#    {'is_past': True, 'title': 'Internationalization Growth'},
#    {'is_past': True, 'title': 'Director of Media Sales'},
#    {'is_past': True, 'title': 'Senior Product Designer'},
#    {'is_past': True, 'title': 'Head of International Business Development'},
#    {'is_past': True, 'title': 'Country Manager - Brazil'},
#    {'is_past': True, 'title': 'Strategist'},
#    {'is_past': True, 'title': 'Ad Operations Associate'},
#    {'is_past': True, 'title': 'Consultant'},
#    {'is_past': True, 'title': 'Software developer'},
#    {'is_past': True, 'title': 'Product Manager Photos'},
#    {'is_past': True, 'title': 'Tech Lead'},
#    {'is_past': True, 'title': 'Director, Engineering'},
#    {'is_past': True,
#     'title': 'Director of Engineering and Director of Developer Relations'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Platform Operations MBA Intern'},
#    {'is_past': True, 'title': 'Software Engineer / Manager'},
#    {'is_past': True, 'title': 'Product Manager, Pages'},
#    {'is_past': True, 'title': 'Software Engineer, Intern'},
#    {'is_past': True, 'title': 'Mobile Platform Product Marketing'},
#    {'is_past': True, 'title': 'Manager, Corporate Communications'},
#    {'is_past': True, 'title': 'Global Partnership Lead'},
#    {'is_past': True, 'title': 'Consumer Brand and Marketing Intern'},
#    {'is_past': True, 'title': 'Designer'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': "Led FB's Android Products"},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'core infrastructure systems'},
#    {'is_past': True, 'title': 'Great Success'},
#    {'is_past': True, 'title': 'random stuff'},
#    {'is_past': True, 'title': 'Director, Engineering'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director, Platform'},
#    {'is_past': True, 'title': 'Internet Marketer - User Growth'},
#    {'is_past': True, 'title': 'Engineer'},
#    {'is_past': True, 'title': 'Strategy & Business Development'},
#    {'is_past': True, 'title': 'Engineer'},
#    {'is_past': True, 'title': 'Site Reliability Engineer'},
#    {'is_past': True, 'title': 'Production Engineer'},
#    {'is_past': True, 'title': 'Communications Design'},
#    {'is_past': True, 'title': 'Freelance Java/C# developer'},
#    {'is_past': True, 'title': 'Platform & Consumer Marketing'},
#    {'is_past': True, 'title': 'Board Member'},
#    {'is_past': True,
#     'title': 'Director of Global Communications & Public Policy'},
#    {'is_past': True, 'title': 'Corporate Counsel'},
#    {'is_past': True, 'title': 'Deputy General Counsel'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Manager, EMEA Gaming'},
#    {'is_past': True, 'title': 'Product Designer'},
#    {'is_past': True, 'title': 'Director, Corporate Communications'},
#    {'is_past': True, 'title': 'CTO'},
#    {'is_past': True, 'title': 'Director of Platform Partnerships'},
#    {'is_past': True, 'title': 'Product Lead for Facebook Platform'},
#    {'is_past': True, 'title': 'President & Board Member'},
#    {'is_past': True, 'title': 'Manager, Data'},
#    {'is_past': True, 'title': 'Product Designer'},
#    {'is_past': True, 'title': 'Interaction Designer'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director of Engineering'},
#    {'is_past': True, 'title': 'Advisor'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director of Engineering'},
#    {'is_past': True, 'title': 'Advisor'},
#    {'is_past': True, 'title': 'Director, International Business Development'},
#    {'is_past': True, 'title': 'Manager Corporate Development'},
#    {'is_past': True, 'title': 'Director, Media Sales'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director, Finance'},
#    {'is_past': True,
#     'title': 'Dir of Platform Partnerships, Asia-Pacific/Japan'},
#    {'is_past': True, 'title': 'Mobile'},
#    {'is_past': True, 'title': 'Business Development, Mobile'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'IT Specialist'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Sr. International University Recruiter'},
#    {'is_past': True, 'title': 'Investor'},
#    {'is_past': True, 'title': 'All things Operations'},
#    {'is_past': True, 'title': 'Head of Global SMB Marketing'},
#    {'is_past': True, 'title': 'SMB Marketing Manager'},
#    {'is_past': True, 'title': 'Product Director, Ads'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Analyst, writer and project manager'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Product Management'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Partner Engineer'},
#    {'is_past': True, 'title': 'Head of International Growth'},
#    {'is_past': True, 'title': 'Sales Director - Partnerships and Marketing'},
#    {'is_past': True, 'title': 'Software Engineering Manager'},
#    {'is_past': True, 'title': 'Product Design Lead'},
#    {'is_past': True, 'title': 'Search Engineer'},
#    {'is_past': True,
#     'title': 'Senior Director Search Products and Local Business Products'},
#    {'is_past': True, 'title': 'Photos and Video Engineering Manager'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Regional Director'},
#    {'is_past': True, 'title': 'Payments Partnerships & Mobile Payments'},
#    {'is_past': True,
#     'title': 'Business Operations Associate/Principal, User Operations'},
#    {'is_past': True, 'title': 'Business Operations - Program Manager'},
#    {'is_past': True, 'title': 'Account Specialist - Associate'},
#    {'is_past': True, 'title': 'Summer Intern'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director of Operations'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Growth Manager'},
#    {'is_past': True, 'title': 'Manager of Data Science and Analytics'},
#    {'is_past': True, 'title': 'Data Analyst'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Global Marketing Solutions'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Head of Mobile Partnerships, Asia'}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297de0'),
#   'name': 'Yelp',
#   'relationships': [{'is_past': False, 'title': 'co-founder'},
#    {'is_past': False, 'title': 'Chairman & Board Director'},
#    {'is_past': False, 'title': 'Co-founder and CEO'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False, 'title': 'COO'},
#    {'is_past': False, 'title': 'Vice President, Local Sales'},
#    {'is_past': False, 'title': 'Vice President, Business Products'},
#    {'is_past': False, 'title': 'Vice President of New Markets'},
#    {'is_past': False, 'title': 'Vice President, North American Marketing'},
#    {'is_past': False, 'title': 'VP of Corporate Communic'},
#    {'is_past': False, 'title': 'Senior Vice President of Global Sales'},
#    {'is_past': False, 'title': 'General Counsel'},
#    {'is_past': False, 'title': 'Member, Board of Directors'},
#    {'is_past': False,
#     'title': 'Vice President of Business and Corporate Development'},
#    {'is_past': False, 'title': 'Vice President, Engineering'},
#    {'is_past': False, 'title': 'VP, Revenue & Analytics'},
#    {'is_past': False, 'title': 'Director, Business Products'},
#    {'is_past': False, 'title': 'Android Developer'},
#    {'is_past': False, 'title': 'Board Member'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Tech Lead'},
#    {'is_past': False,
#     'title': 'Vice President, Consumer & Mobile Productser and Mobile Products'},
#    {'is_past': False, 'title': 'Global Head of Human Resources'},
#    {'is_past': False, 'title': 'Sales Account Executive'},
#    {'is_past': True, 'title': 'Co-founder and CTO'},
#    {'is_past': True, 'title': 'CFO'},
#    {'is_past': True, 'title': 'Vice President of European Marketing'},
#    {'is_past': True, 'title': 'Vice President of Sales'},
#    {'is_past': True, 'title': 'VP of Engineering'},
#    {'is_past': True, 'title': 'Vice President, Marketing'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Marketing Consultant'},
#    {'is_past': True, 'title': 'Marketing Director'},
#    {'is_past': True, 'title': 'Account Executive'},
#    {'is_past': True, 'title': 'iOS Developer'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Senior Business Intelligence Analyst'},
#    {'is_past': True, 'title': 'Regional Marketing Director'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Key Account Executive'},
#    {'is_past': True, 'title': 'VP, Marketing'},
#    {'is_past': True, 'title': 'Director of Sales / West'},
#    {'is_past': True, 'title': 'Advisor'},
#    {'is_past': True, 'title': 'Senior Account Executive'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Senior Engineer'},
#    {'is_past': True, 'title': 'Director of Engineering'},
#    {'is_past': True, 'title': 'Director of Consumer & Mobile Products'},
#    {'is_past': True, 'title': 'Account Executive'},
#    {'is_past': True, 'title': 'Business Development'}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da3'),
#   'name': 'Yahoo!',
#   'relationships': [{'is_past': False, 'title': 'CEO, President'},
#    {'is_past': False, 'title': 'Non-Executive Chairman and Advisor'},
#    {'is_past': False, 'title': 'Co-Founder and Chief Yahoo'},
#    {'is_past': False, 'title': 'Chief Financial Officer'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False, 'title': 'Chief Operating Officer'},
#    {'is_past': False, 'title': 'Chief Marketing Officer'},
#    {'is_past': False, 'title': 'CIO Corporate Systems'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False,
#     'title': 'Chief Strategy Officer, Executive Vice President, and Head'},
#    {'is_past': False, 'title': 'VP & Head, Yahoo Small Business'},
#    {'is_past': False, 'title': 'Senior Vice President'},
#    {'is_past': False, 'title': 'Senior Vice President'},
#    {'is_past': False, 'title': 'VP & Co-Head of Corporate Development'},
#    {'is_past': False, 'title': 'VP Corp Dev'},
#    {'is_past': False, 'title': 'VP, Engineering - interclick by Yahoo!'},
#    {'is_past': False, 'title': 'Vice President, Mobile Search'},
#    {'is_past': False,
#     'title': 'Senior Vice President, Display Advertising and Advertising Technology'},
#    {'is_past': False, 'title': 'VP, Mobile Products'},
#    {'is_past': False, 'title': 'SVP Global Talent Acquisition'},
#    {'is_past': False, 'title': 'VP Engineering, Media Publishing'},
#    {'is_past': False,
#     'title': 'VVP Engineering - Personalization and Display Ad Targeting'},
#    {'is_past': False,
#     'title': 'VP North American Sales and Global Partnerships'},
#    {'is_past': False, 'title': 'SVP, Emerging Products and Technology'},
#    {'is_past': False, 'title': 'Vice President, Business Development'},
#    {'is_past': False,
#     'title': 'Executive Vice President, General Counsel and Secretary'},
#    {'is_past': False, 'title': 'Senior Vice President'},
#    {'is_past': False, 'title': 'board of directors'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False,
#     'title': 'Vice President & Research Fellow, Yahoo Research'},
#    {'is_past': False, 'title': 'Senior Director of User Experience in Search'},
#    {'is_past': False,
#     'title': 'Executive Vice President, Service Engineering & Operations'},
#    {'is_past': False, 'title': 'System Engineer'},
#    {'is_past': False, 'title': 'Content Producer'},
#    {'is_past': False, 'title': 'Consultant'},
#    {'is_past': False, 'title': 'SVP, Design'},
#    {'is_past': False, 'title': 'Sr.Director, Product Management'},
#    {'is_past': False, 'title': 'Sr.Software Engineer'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Seniour Technical'},
#    {'is_past': False, 'title': 'Principle Engineer'},
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Product Manager / Mobile'},
#    {'is_past': False, 'title': 'Consultant'},
#    {'is_past': False, 'title': 'senior operating positions'},
#    {'is_past': False, 'title': 'Director'},
#    {'is_past': False, 'title': 'Director, Product Management'},
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'Senior Front-end Engineer'},
#    {'is_past': False, 'title': 'Senior Manager: Y! Music Sales Programs'},
#    {'is_past': False, 'title': 'Principal Software Engineer'},
#    {'is_past': False, 'title': 'Head of Global Agency & Client Development'},
#    {'is_past': False, 'title': 'Senior Principal Architect'},
#    {'is_past': False, 'title': 'Director Of Marketing Solutions'},
#    {'is_past': False, 'title': 'Director of Engineering, Yahoo Games'},
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'Chairperson of Audit & Finance Committee'},
#    {'is_past': False, 'title': 'Team Member'},
#    {'is_past': False, 'title': 'Team Member'},
#    {'is_past': False, 'title': 'Consumer Tech Writer'},
#    {'is_past': False, 'title': 'Global Anchor'},
#    {'is_past': False, 'title': 'Executive Vice Presiden'},
#    {'is_past': False, 'title': 'Boards of Director'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Board Director'},
#    {'is_past': False, 'title': 'Principal Research Scientist'},
#    {'is_past': False, 'title': 'Engineering'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False, 'title': 'Senior Software Engineer'},
#    {'is_past': False,
#     'title': 'Senior Product Manager, Yahoo! Developer Network'},
#    {'is_past': False, 'title': 'Global Head of Product, Yahoo! Games'},
#    {'is_past': False, 'title': 'VP, Flickr'},
#    {'is_past': False, 'title': 'Database Geek'},
#    {'is_past': False, 'title': 'Technical Lead'},
#    {'is_past': False, 'title': 'Chief Development Officer'},
#    {'is_past': False, 'title': 'Director'},
#    {'is_past': False, 'title': 'Principal Engineer'},
#    {'is_past': False, 'title': 'Sr. Director, Product Management'},
#    {'is_past': False, 'title': 'Software development engineer'},
#    {'is_past': False, 'title': 'Research Scientist'},
#    {'is_past': False, 'title': 'Senior Vice President of Search Products'},
#    {'is_past': False, 'title': 'Contributor and Columnist'},
#    {'is_past': False, 'title': 'Corporate Communications'},
#    {'is_past': False, 'title': 'Director Product Management, Yahoo'},
#    {'is_past': False,
#     'title': 'Director of Product Management, Yahoo! Weather'},
#    {'is_past': False, 'title': 'Head of Audience, Southeast Asia'},
#    {'is_past': False, 'title': 'Senior Director of Product Marketing'},
#    {'is_past': False, 'title': 'Senior Director of Engineering'},
#    {'is_past': False,
#     'title': 'Exec. Director, Global Agency Development at Yahoo!'},
#    {'is_past': False, 'title': 'Executive Director, Sales'},
#    {'is_past': False, 'title': 'GM, Yahoo! Games'},
#    {'is_past': False, 'title': 'Director of Product, Games'},
#    {'is_past': False, 'title': 'Senior Director'},
#    {'is_past': False, 'title': 'Team Member'},
#    {'is_past': False, 'title': 'Team Member'},
#    {'is_past': False, 'title': 'Team Member'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': False, 'title': 'Head of the Americas'},
#    {'is_past': False, 'title': 'Boards of Director'},
#    {'is_past': True, 'title': 'CEO - Europe'},
#    {'is_past': True, 'title': 'CEO'},
#    {'is_past': True,
#     'title': 'Director - Business Operations, Office of the CEO'},
#    {'is_past': True, 'title': 'Zimbra co-founder'},
#    {'is_past': True, 'title': 'Co-Founder'},
#    {'is_past': True, 'title': 'CORE Founder, Engineering Lead'},
#    {'is_past': True, 'title': 'CEO'},
#    {'is_past': True, 'title': 'Founder and Sr. Director - Yahoo! Voice'},
#    {'is_past': True, 'title': 'CEO'},
#    {'is_past': True, 'title': 'President and CEO'},
#    {'is_past': True, 'title': 'VP, Chief Cloud Architect'},
#    {'is_past': True, 'title': 'Chief Product Officer'},
#    {'is_past': True, 'title': 'Chief Accounting Officer'},
#    {'is_past': True, 'title': 'CFO'},
#    {'is_past': True,
#     'title': 'Sr. Director of Engineering - Advertising Management Platform (AMP), Director of Engineering & CTO of HotJobs'},
#    {'is_past': True, 'title': 'Chief of Staff, Community Products'},
#    {'is_past': True, 'title': 'VP, Chief Architect of Search and Advertising'},
#    {'is_past': True, 'title': 'Chief Scientist, Audience and Cloud Computing'},
#    {'is_past': True, 'title': 'Chief Communications Officer'},
#    {'is_past': True, 'title': 'Chief Information Security Officer (CISO)'},
#    {'is_past': True, 'title': 'Global CRO'},
#    {'is_past': True, 'title': 'Chief Privacy Officer'},
#    {'is_past': True,
#     'title': 'Executive Vice President, Chief Product Officer'},
#    {'is_past': True, 'title': "VP, Yahoo!'s Chief Architect"},
#    {'is_past': True, 'title': 'Chief Technical Monkey'},
#    {'is_past': True, 'title': 'Chief Technologist'},
#    {'is_past': True, 'title': 'Europe Chief Architect'},
#    {'is_past': True, 'title': 'Chief Pixel Thief'},
#    {'is_past': True, 'title': 'Chief Human Resources Officer'},
#    {'is_past': True, 'title': 'CTO Yahoo Music/Launch'},
#    {'is_past': True, 'title': 'Chief Product Officer'},
#    {'is_past': True, 'title': 'Chief Insights Officer'},
#    {'is_past': True, 'title': 'Chief Scientist, Yahoo Connected Life'},
#    {'is_past': True, 'title': 'CChief Communications Officer, SVP'},
#    {'is_past': True,
#     'title': 'Chief Technical Officer and Senior Vice President of Communication Services'},
#    {'is_past': True, 'title': 'President and COO'},
#    {'is_past': True,
#     'title': 'Chief Data Officer and Executive Vice President, Research & Strategic Data Solutions'},
#    {'is_past': True, 'title': 'Executive Vice President of Products & CTO'},
#    {'is_past': True, 'title': 'COO'},
#    {'is_past': True, 'title': 'Vice President Network Quality and Operations'},
#    {'is_past': True, 'title': 'VP Deputy General Counsel, International'},
#    {'is_past': True, 'title': 'VP, Engineering - Media & Entertainment'},
#    {'is_past': True, 'title': 'Vice President of Business Development'},
#    {'is_past': True,
#     'title': 'VP, Advertising Sales Operations - North America'},
#    {'is_past': True, 'title': 'VP, Data Center Engineering & Operations'},
#    {'is_past': True,
#     'title': 'VP Financial Planning and Investor Relations; Corp Controller'},
#    {'is_past': True, 'title': 'VP, Global Strategic Partnerships'},
#    {'is_past': True, 'title': 'VP, Data Strategy'},
#    {'is_past': True, 'title': 'Vice President - Yahoo! Mail'},
#    {'is_past': True, 'title': 'VP, Content Optimization'},
#    {'is_past': True, 'title': 'Vice President and GM, Display Advertising'},
#    {'is_past': True, 'title': 'VP of Business Affairs'},
#    {'is_past': True, 'title': 'Vice President/General Manager'},
#    {'is_past': True, 'title': 'VP / GM, Yahoo! News & Info, Yahoo! Originals'},
#    {'is_past': True, 'title': 'Regional Vice President Sales - Northwest'},
#    {'is_past': True, 'title': 'Vice President, General Manager'},
#    {'is_past': True, 'title': 'VP, Corporate Partners'},
#    {'is_past': True,
#     'title': 'Senior Vice President - Revenue and Market Development'},
#    {'is_past': True,
#     'title': 'Regional Vice President and Managing Director, North Asia at Yahoo Inc.'},
#    {'is_past': True, 'title': 'SVP Finance'},
#    {'is_past': True, 'title': 'Vice President, Products'},
#    {'is_past': True, 'title': 'VP & Assoc. General Counsel'},
#    {'is_past': True, 'title': 'SVP/GM, Global Exchange'},
#    {'is_past': True, 'title': 'Vice President, Operations Finance'},
#    {'is_past': True, 'title': 'VP, Emerging Businesses'},
#    {'is_past': True, 'title': 'SVP Commerce & VP/GM Shopping'},
#    {'is_past': True, 'title': 'VP and General Manager, Music'},
#    {'is_past': True, 'title': 'VP, Optimization & Analytics'},
#    {'is_past': True, 'title': 'VP, Product'},
#    {'is_past': True, 'title': 'Vice President, Operations Finance'},
#    {'is_past': True, 'title': 'Senior Vice President'},
#    {'is_past': True, 'title': 'VP, Engineering - Yahoo! Search Marketing'},
#    {'is_past': True,
#     'title': 'Senior Vice President Strategic Content Relations'},
#    {'is_past': True, 'title': 'Vice President Engineering'},
#    {'is_past': True, 'title': 'VP Business Operations'},
#    {'is_past': True, 'title': 'VP International Finance'},
#    {'is_past': True, 'title': 'VP of Content Storage, Delivery, and Edge'},
#    {'is_past': True, 'title': 'VP, General Manager'},
#    {'is_past': True, 'title': 'Vice President, Product Justice'},
#    {'is_past': True,
#     'title': 'SVP Broadband, Affiliate Search & Business Development'},
#    {'is_past': True, 'title': 'VP'},
#    {'is_past': True, 'title': 'VP'},
#    {'is_past': True, 'title': 'VP of ESP'},
#    {'is_past': True, 'title': 'SVP / GM, Communications'},
#    {'is_past': True, 'title': 'Vice President, Engineering'},
#    {'is_past': True, 'title': 'Vice President, Business Management'},
#    {'is_past': True, 'title': 'Senior Vice President of Applications'},
#    {'is_past': True,
#     'title': 'B2B Marketing - Industry Outreach, Interim Vice President, B2B Marketing'},
#    {'is_past': True, 'title': 'Vice President'},
#    {'is_past': True,
#     'title': 'Head of Yahoo Spot Marketing, VP Business Development'},
#    {'is_past': True, 'title': 'VP, Operations Management'},
#    {'is_past': True, 'title': 'EVP, Americas'},
#    {'is_past': True, 'title': 'VP Marketing, Yahoo! Search and Social Media'},
#    {'is_past': True, 'title': 'Vice President, Yahoo! Media Sales'},
#    {'is_past': True,
#     'title': 'Vice President and General Manager - European Search and Social Media'},
#    {'is_past': True, 'title': 'VP Search Platform'},
#    {'is_past': True, 'title': 'Group Vice President'},
#    {'is_past': True, 'title': 'Vice President, North American Audience'},
#    {'is_past': True, 'title': 'VP, Y! Search Business'},
#    {'is_past': True, 'title': 'Group Vice Presiden'},
#    {'is_past': True, 'title': 'Senior Vice President, Engineering/Operations'},
#    {'is_past': True, 'title': 'EVP Americas'},
#    {'is_past': True,
#     'title': 'SVP, Audience Experiences, North America Region'},
#    {'is_past': True, 'title': 'Vice President Human Resources'},
#    {'is_past': True, 'title': 'EVP, Head of Global Media'},
#    {'is_past': True,
#     'title': 'SVP, Small Business and Recruitment Advertising'},
#    {'is_past': True,
#     'title': 'Vice President Yahoo Search and Display Network'},
#    {'is_past': True, 'title': 'VP, Corporate & Mobile Strategy'},
#    {'is_past': True, 'title': 'SVP, Global Initiatives'},
#    {'is_past': True, 'title': 'Vice President, Business Development'},
#    {'is_past': True, 'title': 'Vice President'},
#    {'is_past': True, 'title': 'Managing Director/VP, Corp Dev'},
#    {'is_past': True, 'title': 'VP, Category and Sales Intelligence'},
#    {'is_past': True, 'title': 'Group Vice President'},
#    {'is_past': True,
#     'title': 'Vice-President Sales Communication and Training'},
#    {'is_past': True, 'title': 'VP, Human Resources - China'},
#    {'is_past': True, 'title': 'VP, Engineering'},
#    {'is_past': True, 'title': 'Vice President, Community'},
#    {'is_past': True, 'title': 'VP - Broadcast Interactive Group'},
#    {'is_past': True, 'title': 'VP Political Advertising'},
#    {'is_past': True, 'title': 'VP Business Development'},
#    {'is_past': True, 'title': 'VP Yahoo! Search'},
#    {'is_past': True, 'title': 'VP of North American field sales'},
#    {'is_past': True, 'title': 'EVP, Audience Technology'},
#    {'is_past': True, 'title': 'VP Mobile Advertisers and Publishers'},
#    {'is_past': True, 'title': 'VP, International Business Development'},
#    {'is_past': True, 'title': 'VP Media Sales - North America'},
#    {'is_past': True, 'title': 'Senior Vice President - Business Operations'},
#    {'is_past': True, 'title': 'VP, Advertiser Product Marketing'},
#    {'is_past': True, 'title': 'Group VP/General Manager: Local & Commerce'},
#    {'is_past': True, 'title': 'Vice President, Engineering, Search Products'},
#    {'is_past': True, 'title': 'VP Platforms'},
#    {'is_past': True, 'title': 'VP, Search Market Share Initiative'},
#    {'is_past': True, 'title': 'VP Global Product Marketing and Biz Dev'},
#    {'is_past': True, 'title': 'VP Corporate Development'},
#    {'is_past': True, 'title': 'VP, Display Advertising'},
#    {'is_past': True, 'title': 'SVP ECommerce'},
#    {'is_past': True, 'title': 'VP Sales'},
#    {'is_past': True, 'title': 'Senior Vice President'},
#    {'is_past': True, 'title': 'VP, Customer Insights'},
#    {'is_past': True,
#     'title': 'Senior Vice President International Operations'},
#    {'is_past': True, 'title': 'VP Engineering, Ad Systems'},
#    {'is_past': True, 'title': 'Vice President - Search and Yahoo Answers'},
#    {'is_past': True, 'title': 'EVP Americas'},
#    {'is_past': True, 'title': 'Vice President, Yahoo! Media Group'},
#    {'is_past': True, 'title': 'SVP'},
#    {'is_past': True, 'title': 'SVP Search Division Worldwide'},
#    {'is_past': True,
#     'title': 'Vice President Global Corp Dev: M&A-Integration & Strategic Partnerships'},
#    {'is_past': True, 'title': 'VP Speech Strategy'},
#    {'is_past': True, 'title': 'SVP, Media Products and Solutions'},
#    {'is_past': True, 'title': 'VP Engineering'},
#    {'is_past': True, 'title': 'Vice President, Corporate Development'},
#    {'is_past': True,
#     'title': 'Vice President of Marketing Yahoo! Network Division'},
#    {'is_past': True, 'title': 'SVP, Chief Technology Officer'},
#    {'is_past': True, 'title': 'Vice President, Professional Services'},
#    {'is_past': True,
#     'title': 'Executive Vice President, Product Architecture & Strategy'},
#    {'is_past': True,
#     'title': 'Vice President, Corporate Communications for Products and Technology'},
#    {'is_past': True,
#     'title': 'VP, Product Management and Design, Yahoo! Search'},
#    {'is_past': True,
#     'title': 'Senior Vice President, Yahoo & GM of Yahoo HotJobs'},
#    {'is_past': True, 'title': 'VP, Mobile'},
#    {'is_past': True, 'title': 'Vice President & General Manager'},
#    {'is_past': True, 'title': 'VP, GM Marketplace'},
#    {'is_past': True, 'title': 'VP Product Management, Connected TV Group'},
#    {'is_past': True, 'title': 'VP Head of Audience - Europe'},
#    {'is_past': True,
#     'title': 'VP, Broadband, Consumer Services, Digital Home'},
#    {'is_past': True, 'title': 'VP Engineering'},
#    {'is_past': True, 'title': 'VP Web Search Technology'},
#    {'is_past': True,
#     'title': 'Senior Vice President of Applications Products'},
#    {'is_past': True, 'title': 'SVP Business Operations'},
#    {'is_past': True, 'title': 'VP of Operations for Search'},
#    {'is_past': True, 'title': 'Vice President, General Manager'},
#    {'is_past': True, 'title': 'Regional Vice President'},
#    {'is_past': True, 'title': 'VP Community'},
#    {'is_past': True, 'title': 'Vice President, B2B Marketing'},
#    {'is_past': True, 'title': 'VP, Global Customer Care'},
#    {'is_past': True, 'title': 'Vice President, Northwest Region'},
#    {'is_past': True, 'title': 'SVP/VP, Applications'},
#    {'is_past': True, 'title': 'VP, Product Management'},
#    {'is_past': True, 'title': 'VP, Communities'},
#    {'is_past': True,
#     'title': 'VP and General Manager, Media and Entertainment'},
#    {'is_past': True, 'title': 'Senior Vice President'},
#    {'is_past': True, 'title': 'VP, Media'},
#    {'is_past': True, 'title': 'Vice President Engineering'},
#    {'is_past': True, 'title': 'VP/GM, Local'},
#    {'is_past': True, 'title': 'VP, Associate General Counsel'},
#    {'is_past': True, 'title': 'Senior Vice President'},
#    {'is_past': True, 'title': 'VP, Marketing, Search & Marketplace'},
#    {'is_past': True,
#     'title': 'Executive Vice President of Engineering for Search and Search Marketing'},
#    {'is_past': True, 'title': 'Vice President, General Counsel and Secretary'},
#    {'is_past': True, 'title': 'Senior Vice President, Media and Leisure'},
#    {'is_past': True,
#     'title': 'Senior Vice President, Network and Commerce Services'},
#    {'is_past': True,
#     'title': 'Senior Vice President, Head of Yahoo! Entertainment'},
#    {'is_past': True,
#     'title': 'Executive Vice President, Yahoo! North America'},
#    {'is_past': True,
#     'title': 'Senior Vice President, Integrated Consumer Experiences'},
#    {'is_past': True, 'title': 'VP of Engineering, Yahoo! Messenger'},
#    {'is_past': True, 'title': 'Executive Vice President, Network Division'},
#    {'is_past': True, 'title': 'Vice President of Social Search'},
#    {'is_past': True, 'title': 'Senior Vice President of Finance'},
#    {'is_past': True, 'title': 'VP of Platform Engineering'},
#    {'is_past': True,
#     'title': 'Treasurer and Senior Vice President of Finance'},
#    {'is_past': True, 'title': 'Senior Director, Yahoo! TV'},
#    {'is_past': True, 'title': 'Director , Product Management, Connected Life'},
#    {'is_past': True, 'title': 'Director of Marketing'},
#    {'is_past': True, 'title': 'Chief Architect, Platforms'},
#    {'is_past': True,
#     'title': 'Product Manager / Engineering Lead (sled.com) / Director of Standards Development'},
#    {'is_past': True, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'GM & SVP, Yahoo! Search'},
#    {'is_past': True, 'title': 'Snr Director Product Mgmnt'},
#    {'is_past': True, 'title': 'Senior Director Insight Strategy'},
#    {'is_past': True, 'title': 'SVP of News & Information'},
#    {'is_past': True, 'title': 'VP, Advanced Development'},
#    {'is_past': True,
#     'title': 'Executive Vice President, North American Operations'},
#    {'is_past': True,
#     'title': 'Senior Vice President, Entertainment and Small Business'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Director of Product Management'},
#    {'is_past': True, 'title': 'Creative Director'},
#    {'is_past': True, 'title': 'SVP of Strategic Alliances'},
#    {'is_past': True, 'title': 'Head of Music'},
#    {'is_past': True, 'title': 'Head of Engineering, Real Time Communications'},
#    {'is_past': True, 'title': 'Senior Director of Marketing'},
#    {'is_past': True,
#     'title': 'Search & Social Search Director - Senior European Director'},
#    {'is_past': True, 'title': 'Sr. Engineer'},
#    {'is_past': True, 'title': 'Sr Technical Yahoo!'},
#    {'is_past': True, 'title': 'Maps Sr. Flash Developer'},
#    {'is_past': True, 'title': 'Head, Music'},
#    {'is_past': True, 'title': 'Sr. PR Manager'},
#    {'is_past': True, 'title': 'SVP Connected Life'},
#    {'is_past': True, 'title': 'Director Communications'},
#    {'is_past': True, 'title': 'Web Development Manager, Search'},
#    {'is_past': True, 'title': 'Product Management'},
#    {'is_past': True, 'title': 'Platform Group'},
#    {'is_past': True, 'title': 'Principal Research Scientist, Microeconomics'},
#    {'is_past': True, 'title': 'RVP Sales'},
#    {'is_past': True,
#     'title': 'Sr. Scientist Associate (Data Mining & Research Group)'},
#    {'is_past': True, 'title': 'Brickhouse Senior Designer'},
#    {'is_past': True, 'title': 'Product Manager, Messenger Voice Team'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Search Marketing Manager'},
#    {'is_past': True, 'title': 'Executive Director, Northwest Sales'},
#    {'is_past': True, 'title': 'Interaction Designer - Yahoo Messenger'},
#    {'is_past': True,
#     'title': 'Director, Business Development & Sales Programs'},
#    {'is_past': True, 'title': 'Director, User Experience Design'},
#    {'is_past': True, 'title': 'GM, Entertainment'},
#    {'is_past': True, 'title': 'EVP, Chief Marketing Officer'},
#    {'is_past': True, 'title': 'Sr. Product Manager'},
#    {'is_past': True, 'title': 'Tech Lead, Search Relevance Group'},
#    {'is_past': True, 'title': 'General Manager, Lead Generation'},
#    {'is_past': True, 'title': 'Product Director, Custom Brand Experience'},
#    {'is_past': True, 'title': 'Principal'},
#    {'is_past': True, 'title': 'Product Manager, Game Services'},
#    {'is_past': True, 'title': 'Developer, Yahoo! Brickhouse'},
#    {'is_past': True, 'title': 'Director of Data Insights'},
#    {'is_past': True, 'title': 'User Experience Design'},
#    {'is_past': True, 'title': 'Director of Architecture'},
#    {'is_past': True, 'title': 'Sr. PM Product Strategy Group Digital Home'},
#    {'is_past': True, 'title': 'Corporate Communications'},
#    {'is_past': True, 'title': 'Director, Business Development'},
#    {'is_past': True, 'title': 'Sr. Product Designer'},
#    {'is_past': True, 'title': 'Infrastructure Engineer'},
#    {'is_past': True, 'title': 'Senior Product Manager'},
#    {'is_past': True, 'title': 'Site Architect, BOSS'},
#    {'is_past': True, 'title': 'Direct Product Management'},
#    {'is_past': True,
#     'title': 'Senior Director, Product Management, Yahoo! Groups'},
#    {'is_past': True, 'title': 'Sr. VP, Connections Business Unit'},
#    {'is_past': True, 'title': 'Senior Product Manager'},
#    {'is_past': True, 'title': 'Sr. Director, Product Strategy'},
#    {'is_past': True, 'title': 'Director of Technical Marketing'},
#    {'is_past': True, 'title': 'Front End Engineer, YUI Library'},
#    {'is_past': True, 'title': 'Technical Yahoo!'},
#    {'is_past': True, 'title': 'Director Engineering'},
#    {'is_past': True, 'title': 'Director and Head of Engineering, MENA'},
#    {'is_past': True, 'title': 'Catalyst (Brickhouse)'},
#    {'is_past': True, 'title': 'Chief Architect, Yahoo! BOSS'},
#    {'is_past': True, 'title': 'Director, User Experience Design'},
#    {'is_past': True, 'title': 'Product Marketing'},
#    {'is_past': True, 'title': 'Director of Engineering, Geo'},
#    {'is_past': True, 'title': 'Sr. Director, Client Services'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Developer'},
#    {'is_past': True, 'title': 'Flickr Architect'},
#    {'is_past': True, 'title': 'Prototype Design Lead'},
#    {'is_past': True, 'title': 'Director, Video Production'},
#    {'is_past': True, 'title': 'Senior Director, Strategic Partnerships'},
#    {'is_past': True, 'title': 'Technical Yahoo!'},
#    {'is_past': True, 'title': 'Sr. Director of Product and Design'},
#    {'is_past': True, 'title': 'Sr. Director, Business Management & Strategy'},
#    {'is_past': True, 'title': 'Director of Product - Y! Video'},
#    {'is_past': True, 'title': 'Director, Yahoo! Games'},
#    {'is_past': True, 'title': 'Director of Product Management'},
#    {'is_past': True,
#     'title': 'Managing Director Monetization, Connected Life'},
#    {'is_past': True,
#     'title': 'General Manager, Yahoo! Video and Head of Products, Yahoo! Finance'},
#    {'is_past': True, 'title': 'VP, Product Management'},
#    {'is_past': True, 'title': 'Senior Product Manager'},
#    {'is_past': True, 'title': 'Senior Product Manager'},
#    {'is_past': True, 'title': 'Senior Software Developer'},
#    {'is_past': True,
#     'title': 'Senior Prototyper - Global Product Development'},
#    {'is_past': True, 'title': 'Product Manager, Local Commerce'},
#    {'is_past': True, 'title': 'General Manager, Smart Ads'},
#    {'is_past': True, 'title': 'SEO Program Manager'},
#    {'is_past': True, 'title': 'Ad Partner'},
#    {'is_past': True, 'title': 'Dir of Product Management - Maps & Local'},
#    {'is_past': True, 'title': 'Region Business Leader, News & Information'},
#    {'is_past': True, 'title': 'Product Manager'},
#    {'is_past': True, 'title': 'Advertising Solutions'},
#    {'is_past': True,
#     'title': 'Senior Manager Business Development and Strategy'},
#    {'is_past': True, 'title': 'Senior Engineer'},
#    {'is_past': True, 'title': 'Senior Interaction Designer'},
#    {'is_past': True, 'title': 'Manager, Search Volume Initiatives'},
#    {'is_past': True, 'title': 'Head of entertainment'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True,
#     'title': 'Sr. Product Manager, International Mail & Messenger'},
#    {'is_past': True,
#     'title': 'Director of Operations & Localization - Media Products and Solutions'},
#    {'is_past': True,
#     'title': 'Director of Business Development, Yahoo! Open Strategy'},
#    {'is_past': True, 'title': 'Senior Director, Corporate Development'},
#    {'is_past': True,
#     'title': 'Sr. Director, Engineering - Cloud Service Development'},
#    {'is_past': True, 'title': 'Senior Interaction Designer'},
#    {'is_past': True, 'title': 'Director, Ad Solutions'},
#    {'is_past': True, 'title': 'Sr. Director, Y! Display Ad Network'},
#    {'is_past': True, 'title': 'Sr. Director BD'},
#    {'is_past': True, 'title': 'Managing Director, Account Management'},
#    {'is_past': True, 'title': '"Spam Czar"'},
#    {'is_past': True, 'title': 'QA Lead'},
#    {'is_past': True,
#     'title': 'Sr. Director, Communications and Community User Experience'},
#    {'is_past': True, 'title': 'Design Lead, Enterprise Solutions'},
#    {'is_past': True, 'title': 'Curator, Yahoo Design Pattern Library'},
#    {'is_past': True, 'title': 'Sr. Director, Technical Operations'},
#    {'is_past': True, 'title': 'Frontend Lead'},
#    {'is_past': True, 'title': 'Director, Product Management'},
#    {'is_past': True, 'title': 'Senior Director, Advanced Products Group'},
#    {'is_past': True, 'title': 'Front End Developer'},
#    {'is_past': True, 'title': 'Sr. Director of Corporate Partnerships'},
#    {'is_past': True, 'title': 'Sr. Manager'},
#    {'is_past': True, 'title': 'Senior Director of Engineering'},
#    {'is_past': True, 'title': 'Senior Director, Product Management'},
#    {'is_past': True, 'title': 'Sr Director, Network Field Sales'},
#    {'is_past': True, 'title': 'Head of Business Development UK'},
#    {'is_past': True, 'title': 'Head of Agency Sales UK'},
#    {'is_past': True, 'title': 'International M&A'},
#    {'is_past': True,
#     'title': 'Sr. Director, Product Management, Search and Commerce'},
#    {'is_past': True, 'title': 'Creative Director'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Product Strategy'},
#    {'is_past': True, 'title': 'Senior Director of Product'},
#    {'is_past': True, 'title': 'Sr. Front end Developer'},
#    {'is_past': True, 'title': 'Account Executive'},
#    {'is_past': True, 'title': 'Director, Business Development'},
#    {'is_past': True, 'title': 'Editor at Large, Yahoo! Autos'},
#    {'is_past': True,
#     'title': 'Sr. Director, Sales Development- Ad Products & Emerging Formats (+previous roles 2004-09)'},
#    {'is_past': True,
#     'title': 'Program Manager, Search & Marketplace Analytics'},
# ...
#    {'is_past': False, 'title': ''},
#    {'is_past': False, 'title': 'President'},
#    {'is_past': False, 'title': ''},
#    {'is_past': True, 'title': 'Sales Director'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529aa77'),
#   'name': 'JDS Uniphase Corporation',
#   'relationships': [{'is_past': False, 'title': 'Chairman of the Board'},
#    {'is_past': False, 'title': 'Chairman of the Board'},
#    {'is_past': False,
#     'title': 'Director, President and Chief Operating Officer'},
#    {'is_past': False, 'title': 'Governance Committee Chair'},
#    {'is_past': False, 'title': 'Principal Portfolio Architect'},
#    {'is_past': False, 'title': 'Director'},
#    {'is_past': False, 'title': 'director of advance technology'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': True,
#     'title': 'Senior Vice President & Chief Technology Officer'},
#    {'is_past': True, 'title': 'Vice President'},
#    {'is_past': True,
#     'title': 'Vice President of Strategic & Corporate Marketing'},
#    {'is_past': True, 'title': 'Vice President of Manufacturing Operation'},
#    {'is_past': True,
#     'title': 'VP North America Operation, Op Comms BU, Sales Manager, GM, Shenzhen Site'},
#    {'is_past': True, 'title': 'VP Sales & Marketing'},
#    {'is_past': True, 'title': 'President & Corporate EVP'},
#    {'is_past': True, 'title': 'Manager, Director, VP / GM'},
#    {'is_past': True, 'title': 'Total Rewards'},
#    {'is_past': True, 'title': 'Sales & Marketing Specialist'},
#    {'is_past': True, 'title': 'Site Operations Manager'},
#    {'is_past': True, 'title': 'SVP Optical Communications'},
#    {'is_past': True, 'title': 'Director, Strategic Marketing'},
#    {'is_past': True, 'title': 'Director of Operations; San Jose Sites'},
#    {'is_past': True, 'title': 'Product Development Manager'},
#    {'is_past': True, 'title': 'Director of Network Strategy'},
#    {'is_past': True, 'title': 'Product'},
#    {'is_past': True,
#     'title': 'Director in Operations for the Optical Communications Division'},
#    {'is_past': True, 'title': 'SVP, Global Sales'},
#    {'is_past': True, 'title': 'Direct Sales & Solution Specialist positions'},
#    {'is_past': True, 'title': 'Manufacturing Manager'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Accounting'},
#    {'is_past': True, 'title': 'Global Sales Controller'},
#    {'is_past': True, 'title': 'VP of Sales'},
#    {'is_past': True, 'title': 'Market Development Manager'},
#    {'is_past': True,
#     'title': 'Senior Optical Scientist and Senior Engineering Manager'},
#    {'is_past': True, 'title': 'Senior Management'},
#    {'is_past': True, 'title': 'President of the Laser and Fiber Optic Groups'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True,
#     'title': 'Executive Director / GM - EMEA East & Emerging Markets'},
#    {'is_past': True, 'title': ''}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529aa87'),
#   'name': 'ECI Telecom',
#   'relationships': [{'is_past': False, 'title': 'President and CEO'},
#    {'is_past': False, 'title': 'Executive Vice President & CFO'},
#    {'is_past': False, 'title': 'Executive VP Global Sales and Marketing'},
#    {'is_past': False, 'title': 'Corporate VP Marketing & Sales'},
#    {'is_past': False, 'title': 'Corporate Strategy'},
#    {'is_past': False, 'title': 'Lead the sales'},
#    {'is_past': True, 'title': 'Board Chairman'},
#    {'is_past': True, 'title': 'President & CEO'},
#    {'is_past': True, 'title': 'Chief Strategy Officer'},
#    {'is_past': True, 'title': 'President and Chief Executive Officer'},
#    {'is_past': True, 'title': 'VP Sales'},
#    {'is_past': True, 'title': 'VP & General Manager, Access Line of Business'},
#    {'is_past': True, 'title': 'Corporate VP Global Sales'},
#    {'is_past': True, 'title': 'Senior Marketing Engineer'},
#    {'is_past': True, 'title': 'General Manager ECI Thailand'},
#    {'is_past': True, 'title': 'Customer Credit Manager'},
#    {'is_past': True, 'title': 'Director of New Applications Development'},
#    {'is_past': True, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Training Development Manager'},
#    {'is_past': True, 'title': 'SDH Sales'},
#    {'is_past': True, 'title': 'Frame Relay / ATM Product Manager'},
#    {'is_past': True, 'title': 'Vice President of R&D'},
#    {'is_past': True, 'title': 'President ECI Asia Pacific'},
#    {'is_past': True, 'title': 'Access NMS R&D Department Manager'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True,
#     'title': 'Head of HR, Global Sales & Marketing and Global HR Operations'},
#    {'is_past': True, 'title': 'Practical Engineer Verification group'},
#    {'is_past': True, 'title': 'Pre-Sales Engineer'},
#    {'is_past': True, 'title': 'President CALA'},
#    {'is_past': True, 'title': 'Sales Manager'},
#    {'is_past': True, 'title': 'Board Member'},
#    {'is_past': True, 'title': 'Sales Director'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529ac2e'),
#   'name': 'SparkBase',
#   'relationships': [{'is_past': False,
#     'title': 'Chairman of Board of Directors'},
#    {'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'VP, Product & Program Management'},
#    {'is_past': False, 'title': 'President'},
#    {'is_past': False, 'title': 'Director, Marketing & Loyalty Services'},
#    {'is_past': False, 'title': 'Client Services Director'},
#    {'is_past': False, 'title': 'VP, Software Engineering'},
#    {'is_past': True, 'title': 'COO'},
#    {'is_past': True, 'title': 'VP of Marketing'},
#    {'is_past': True, 'title': 'SVP of Sales'},
#    {'is_past': True, 'title': 'National Sales Manager'},
#    {'is_past': True, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'Controller'},
#    {'is_past': True, 'title': 'Brand Director'},
#    {'is_past': True, 'title': 'CTO'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'Controller'},
#    {'is_past': True, 'title': 'Channel Manager'},
#    {'is_past': True, 'title': 'Marketing Director'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529af63'),
#   'name': 'Mobile Messenger',
#   'relationships': [{'is_past': False, 'title': 'Co-founder & Director'},
#    {'is_past': False, 'title': 'SVP, Sales and Client Services'},
#    {'is_past': False, 'title': 'Board Member'},
#    {'is_past': False, 'title': 'Account Manager'},
#    {'is_past': False, 'title': 'Director of HR and Recruiting'},
#    {'is_past': False, 'title': 'Account Manager'},
#    {'is_past': False, 'title': 'Account Manager'},
#    {'is_past': False, 'title': 'Director of Provisioning and Certification'},
#    {'is_past': False, 'title': 'Director Program Management'},
#    {'is_past': False, 'title': 'Principal Engineer'},
#    {'is_past': False, 'title': 'Payments'},
#    {'is_past': False, 'title': 'Corporate Controller'},
#    {'is_past': False, 'title': 'Sales Director'},
#    {'is_past': False, 'title': 'Human Resources Representative'},
#    {'is_past': False, 'title': 'Director of Finance'},
#    {'is_past': False, 'title': 'Carrier and Content Provider Management'},
#    {'is_past': False, 'title': 'Software Engineer'},
#    {'is_past': False, 'title': 'Web Designer'},
#    {'is_past': True, 'title': 'President / CEO'},
#    {'is_past': True, 'title': 'President and Chief Executive Officer'},
#    {'is_past': True, 'title': 'Chief Technology Officer'},
#    {'is_past': True, 'title': 'SVP, HR'},
#    {'is_past': True, 'title': 'VP Product Development'},
#    {'is_past': True, 'title': 'Manager of Business Development, New Markets'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'CTO'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b326'),
#   'name': 'Conmio',
#   'relationships': [{'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'CTO'},
#    {'is_past': False, 'title': 'Sr VP of Business Development and Sales'},
#    {'is_past': False, 'title': 'VP Business Development'},
#    {'is_past': False, 'title': 'President'},
#    {'is_past': False, 'title': 'Sales Director'},
#    {'is_past': False, 'title': 'Director of Product'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b345'),
#   'name': 'Masterpiece',
#   'relationships': [{'is_past': False, 'title': 'Head of Online'},
#    {'is_past': False, 'title': 'Sales Director'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b4c4'),
#   'name': 'Cloud Testing',
#   'relationships': [{'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'Technical Director'},
#    {'is_past': False, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Sales Manager'},
#    {'is_past': True, 'title': 'Sales Manager'}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b689'),
#   'name': 'Objectivity',
#   'relationships': [{'is_past': False,
#     'title': 'Founder, Chief Technology Officer'},
#    {'is_past': False, 'title': 'Chairman of the Board of Directors'},
#    {'is_past': False, 'title': 'President and CEO'},
#    {'is_past': False, 'title': 'Vice President, Field Services'},
#    {'is_past': False, 'title': 'VP Technical Services'},
#    {'is_past': False, 'title': 'Chief Financial Officer'},
#    {'is_past': False, 'title': 'Vice President of Technical Operations'},
#    {'is_past': False, 'title': 'VP Global Sales'},
#    {'is_past': False, 'title': 'Director of Marketing'},
#    {'is_past': True, 'title': 'President, CEO and Chairman'},
#    {'is_past': True, 'title': 'President and COO'},
#    {'is_past': True, 'title': 'Vice President of Worldwide Sales'},
#    {'is_past': True, 'title': 'Vice President of Sales and Marketing'},
#    {'is_past': True, 'title': 'VP of Marketing'},
#    {'is_past': True, 'title': 'Solution Consultant'},
#    {'is_past': True, 'title': 'Corporate Controller'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Software Architect'},
#    {'is_past': True, 'title': 'Engineer'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Sales Manager for the Eastern Region'},
#    {'is_past': True, 'title': 'Senior Software Engineer'},
#    {'is_past': True,
#     'title': 'Director of Development and Technical Publications'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529bdae'),
#   'name': 'Ergon Informatik',
#   'relationships': [{'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'CFO'},
#    {'is_past': False, 'title': 'HR & Marketing'},
#    {'is_past': False, 'title': 'MD Telecom and Business Solutions'},
#    {'is_past': False, 'title': 'Sales Director'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529beda'),
#   'name': 'Hexaformer',
#   'relationships': [{'is_past': False, 'title': 'President and CEO'},
#    {'is_past': False, 'title': 'Chief Financial Officer'},
#    {'is_past': False, 'title': 'Sales Director'},
#    {'is_past': False, 'title': 'Board'},
#    {'is_past': False, 'title': 'Production Director'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529bfde'),
#   'name': 'Itron',
#   'relationships': [{'is_past': False, 'title': 'President and CEO'},
#    {'is_past': False, 'title': 'Executive Chairman of the Board'},
#    {'is_past': False, 'title': 'Standards and Technology Development'},
#    {'is_past': True, 'title': 'VP Integrated Solutions'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'President of Genesis Services Division'},
#    {'is_past': True, 'title': 'Manager/Sr. Engineer'},
#    {'is_past': True, 'title': 'Senior Software Engineer'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c294'),
#   'name': 'MEDecision',
#   'relationships': [{'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'CFO'},
#    {'is_past': True, 'title': 'EVP & Chief Medical Officer'},
#    {'is_past': True, 'title': 'EVP & Chief Solutions Officer'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Various roles'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c32d'),
#   'name': 'Struq',
#   'relationships': [{'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'Chief Operating Officer'},
#    {'is_past': False, 'title': 'Scientific Engineer'},
#    {'is_past': False, 'title': 'Board Member'},
#    {'is_past': True, 'title': 'CTO'},
#    {'is_past': True, 'title': 'CTO'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Marketing Director'},
#    {'is_past': True, 'title': 'Senior Ad Operations'}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c453'),
#   'name': 'DuPont',
#   'relationships': [{'is_past': False,
#     'title': 'Vice President of Sales and Marketing'},
#    {'is_past': False, 'title': 'Board of directors'},
#    {'is_past': False, 'title': 'management positions in R&D'},
#    {'is_past': False, 'title': 'Graduate Intern'},
#    {'is_past': False, 'title': 'Health Advisory Board'},
#    {'is_past': False, 'title': 'General Manager of the Andean Region'},
#    {'is_past': False, 'title': 'senior vice president of human resources'},
#    {'is_past': False, 'title': 'Managing Director'},
#    {'is_past': True,
#     'title': 'Executive Vice President and Chief Operating Officer'},
#    {'is_past': True, 'title': 'CFO, Senior Vice President'},
#    {'is_past': True, 'title': 'Vice President and General Manager'},
#    {'is_past': True, 'title': 'Group Vice President'},
#    {'is_past': True, 'title': 'Vice President and General Manager'},
#    {'is_past': True, 'title': 'Business Manager Teflon'},
#    {'is_past': True, 'title': 'Patent Counsel'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Production Manager / Customer Service Manager'},
#    {'is_past': True, 'title': 'Business Development Intern Food Industry'},
#    {'is_past': True, 'title': 'eMarketing Specialist'},
#    {'is_past': True, 'title': 'Patent Counsel'},
#    {'is_past': True, 'title': 'Consultant'},
#    {'is_past': True, 'title': 'Various Designation'},
#    {'is_past': True, 'title': 'Scientific Advisor'},
#    {'is_past': True, 'title': 'Corporate Finance Manager'},
#    {'is_past': True, 'title': 'Engineering'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Leadership roles'},
#    {'is_past': True, 'title': 'General Manager'},
#    {'is_past': True, 'title': ''},
#    {'is_past': True, 'title': 'Board of Directors (Danisco A/S)'},
#    {'is_past': True,
#     'title': 'Technology Team Leader /  Sr. Research Associate'},
#    {'is_past': True, 'title': 'Various Positions'},
#    {'is_past': True, 'title': 'Operations Engineer'},
#    {'is_past': True, 'title': 'Treasury Analyst / Global Project Member'},
#    {'is_past': True, 'title': 'Engineering Consultant'},
#    {'is_past': True, 'title': 'Various Designation'},
#    {'is_past': True, 'title': 'Engineer'},
#    {'is_past': True, 'title': 'Various Senior Financial'},
#    {'is_past': True, 'title': 'leadership positions'},
#    {'is_past': True, 'title': 'Supply Chain Analyst'},
#    {'is_past': True,
#     'title': 'Manager (Immunotherapy and Immunodiagnostic R&D Groups'},
#    {'is_past': True, 'title': 'Financial Analyst'},
#    {'is_past': True,
#     'title': 'Global Business Development Manager, Biomaterials & Specialties'},
#    {'is_past': True, 'title': 'Director of Global Strategic Accounts'},
#    {'is_past': True, 'title': 'Director in the Private Markets Group'},
#    {'is_past': True, 'title': ''}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c4a5'),
#   'name': 'Silicon Laboratories',
#   'relationships': [{'is_past': False, 'title': 'Founder/President'},
#    {'is_past': False, 'title': 'CEO'},
#    {'is_past': False, 'title': 'President'},
#    {'is_past': False, 'title': 'Board of Directors'},
#    {'is_past': True, 'title': 'SVP - CFO'},
#    {'is_past': True, 'title': 'Software Engineer'},
#    {'is_past': True, 'title': 'Sales Director'},
#    {'is_past': True, 'title': 'Design Manager'},
#    {'is_past': True,
#     'title': 'Director of Engineering for the Wireline Division'},
#    {'is_past': True, 'title': 'Marketing Management'},
#    {'is_past': True, 'title': 'Corporate Controller'},
#    {'is_past': True, 'title': 'Marketing Manager'},
#    {'is_past': True, 'title': 'Management'},
#    {'is_past': True, 'title': 'Networking Division'},
#    {'is_past': True, 'title': 'Product Marketing Engineer'}]}]

# %% [markdown]
# As we can see this is not quite the result we want, and above query is equal to an AND condition. What we want is each element in the array should meet both the condition

# %%
#if we want to match filter all conditions on a single array element, then we can use "$elemMatch". So there are 19 companies with "Sales Director" right now.

len(list(companyCol.find({"relationships" : {"$elemMatch": {"title": "Sales Director","is_past" : False}}}, {"name": 1,
                                                                                                              "relationships.title" : 1,
                                                                                                             "relationships.is_past":1})))
# Out:
# 19

# %%
#querying companies with only 5 elements in relationships array

len(list(companyCol.find({"relationships" :  { "$size" : 5}}, {"name": 1,"relationships.title" : 1})))
# Out:
# 720

# %% [markdown]
# Couple more complex queries

# %%
list(companyCol.find({"founded_year" : {"$gt" : 2010} , "number_of_employees" : {"$gte" : 50}}, {"founded_year": 1,
                                                                                                  "number_of_employees" : 1,
                                                                                                 "name" : 1}))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd67529801f'),
#   'name': 'Wamba',
#   'number_of_employees': 120,
#   'founded_year': 2013},
#  {'_id': ObjectId('52cdef7c4bab8bd6752982d4'),
#   'name': 'Advaliant',
#   'number_of_employees': 60,
#   'founded_year': 2013},
#  {'_id': ObjectId('52cdef7c4bab8bd67529831a'),
#   'name': 'Social Gaming Network',
#   'number_of_employees': 100,
#   'founded_year': 2011},
#  {'_id': ObjectId('52cdef7c4bab8bd6752983b6'),
#   'name': 'Mobiluck',
#   'number_of_employees': 1234,
#   'founded_year': 2012},
#  {'_id': ObjectId('52cdef7d4bab8bd675299dae'),
#   'name': 'Navara',
#   'number_of_employees': 80,
#   'founded_year': 2012},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b2f3'),
#   'name': '4shared',
#   'number_of_employees': 666,
#   'founded_year': 2011},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c6d4'),
#   'name': 'Treehouse',
#   'number_of_employees': 55,
#   'founded_year': 2011}]

# %%
list(companyCol.find({"$and" : [ {"relationships.title" : "Director of Engineering" }, 
                                {"relationships.title" :"CEO and Co-Founder"}],"founded_year" : {"$gt" : 1990} ,
                      "number_of_employees" : {"$gte" : 50}}, {"founded_year": 1,"number_of_employees" : 1,"name" : 1}))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8b'),
#   'name': 'AdventNet',
#   'number_of_employees': 600,
#   'founded_year': 1996}]

# %%
#lets query in stocks collection,

stockCol.find_one()
# Out:
# {'_id': ObjectId('4d094f58c96767d7a0099d49'),
#  'exchange': 'NASDAQ',
#  'stock_symbol': 'AACC',
#  'date': '2008-03-07',
#  'open': 8.4,
#  'high': 8.75,
#  'low': 8.08,
#  'close': 8.55,
#  'volume': 275800,
#  'adj close': 8.55}

# %%
#lets find stocks which close value is more than the open value.
# $expr is useful command when we want to compare two fields within the same doc

print("Close > Open  :  ",len(list(stockCol.find( { "$expr": { "$gt": [ "$close" , "$open" ] } , "stock_symbol" : "AACC"} ))))
print("Open > Close  :  ",len(list(stockCol.find( { "$expr": { "$gt": [ "$open" , "$close" ] } , "stock_symbol" : "AACC"} ))))
print("Open = Close  :  ",len(list(stockCol.find( { "$expr": { "$eq": [ "$open" , "$close" ] } , "stock_symbol" : "AACC"} ))))
# Out:
# Close > Open  :   499
# Open > Close  :   495
# Open = Close  :   22

# %%
#we can use the where clause to get the same logic, in addition to that, we can perform complex queries like checking the sum of two fields satisfying a condition.

len(list(stockCol.find({"stock_symbol" : "AACC", "$where" : """function() {return this.close > this.open}""" })))

# we can check like this as well
# len(list(stockCol.find({"stock_symbol" : "AACC", "$where" : """function() {return this.close + this.open > 25}""" })))
# Out:
# 866

# %%
# %%time
len(list(stockCol.find( { "$expr": { "$gt": [ "$close" , "$open" ] } } )))
# Out:
# Wall time: 32.4 s
# 1656436

# %%
# %%time
len(list(stockCol.find({"$where" : """function() {return this.close > this.open}""" })))
# Out:
# Wall time: 2min 46s
# 1656436

# %% [markdown]
# As we can see, where takes a lot of time compared to expr, this is because the function we submitted is executed on all the documents.
# More here, https://docs.mongodb.com/manual/reference/operator/query/where/

# %% [markdown]
# Let's do some text matches

# %%
companyCol.find_one()
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297d8b'),
#  'name': 'AdventNet',
#  'permalink': 'abc3',
#  'crunchbase_url': 'http://www.crunchbase.com/company/adventnet',
#  'homepage_url': 'http://adventnet.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'manageengine',
#  'category_code': 'enterprise',
#  'number_of_employees': 600,
#  'founded_year': 1996,
#  'deadpooled_year': 2,
#  'tag_list': '',
#  'alias_list': 'Zoho ManageEngine ',
#  'email_address': 'pr@adventnet.com',
#  'phone_number': '925-924-9500',
#  'description': 'Server Management Software',
#  'created_at': datetime.datetime(2007, 5, 25, 19, 24, 22),
#  'updated_at': 'Wed Oct 31 18:26:09 UTC 2012',
#  'overview': '<p>AdventNet is now <a href="/company/zoho-manageengine" title="Zoho ManageEngine" rel="nofollow">Zoho ManageEngine</a>.</p>\n\n<p>Founded in 1996, AdventNet has served a diverse range of enterprise IT, networking and telecom customers.</p>\n\n<p>AdventNet supplies server and network management software.</p>',
#  'image': {'available_sizes': [[[150, 55],
#     'assets/images/resized/0001/9732/19732v1-max-150x150.png'],
#    [[150, 55], 'assets/images/resized/0001/9732/19732v1-max-250x250.png'],
#    [[150, 55], 'assets/images/resized/0001/9732/19732v1-max-450x450.png']]},
#  'products': [],
#  'relationships': [{'is_past': True,
#    'title': 'CEO and Co-Founder',
#    'person': {'first_name': 'Sridhar',
#     'last_name': 'Vembu',
#     'permalink': 'sridhar-vembu'}},
#   {'is_past': True,
#    'title': 'VP of Business Dev',
#    'person': {'first_name': 'Neil',
#     'last_name': 'Butani',
#     'permalink': 'neil-butani'}},
#   {'is_past': True,
#    'title': 'Usabiliy Engineer',
#    'person': {'first_name': 'Bharath',
#     'last_name': 'Balasubramanian',
#     'permalink': 'bharath-balasibramanian'}},
#   {'is_past': True,
#    'title': 'Director of Engineering',
#    'person': {'first_name': 'Rajendran',
#     'last_name': 'Dandapani',
#     'permalink': 'rajendran-dandapani'}},
#   {'is_past': True,
#    'title': 'Market Analyst',
#    'person': {'first_name': 'Aravind',
#     'last_name': 'Natarajan',
#     'permalink': 'aravind-natarajan'}},
#   {'is_past': True,
#    'title': 'Director of Product Management',
#    'person': {'first_name': 'Hyther',
#     'last_name': 'Nizam',
#     'permalink': 'hyther-nizam'}},
#   {'is_past': True,
#    'title': 'Western Regional OEM Sales Manager',
#    'person': {'first_name': 'Ian',
#     'last_name': 'Wenig',
#     'permalink': 'ian-wenig'}}],
#  'competitions': [],
#  'providerships': [{'title': 'DHFH',
#    'is_past': True,
#    'provider': {'name': 'A Small Orange', 'permalink': 'a-small-orange'}}],
#  'total_money_raised': '$0',
#  'funding_rounds': [],
#  'investments': [],
#  'acquisition': None,
#  'acquisitions': [],
#  'offices': [{'description': 'Headquarters',
#    'address1': '4900 Hopyard Rd.',
#    'address2': 'Suite 310',
#    'zip_code': '94588',
#    'city': 'Pleasanton',
#    'state_code': 'CA',
#    'country_code': 'USA',
#    'latitude': 37.692934,
#    'longitude': -121.904945}],
#  'milestones': [],
#  'video_embeds': [],
#  'screenshots': [{'available_sizes': [[[150, 94],
#      'assets/images/resized/0004/3400/43400v1-max-150x150.png'],
#     [[250, 156], 'assets/images/resized/0004/3400/43400v1-max-250x250.png'],
#     [[450, 282], 'assets/images/resized/0004/3400/43400v1-max-450x450.png']],
#    'attribution': None}],
#  'external_links': [],
#  'partners': []}

# %%
#so there are 1241 companies that starts with A

len(list(companyCol.find({"name": {"$regex" : "^A"}}, {"name" : 1})))
# Out:
# 1241

# %%
len(list(companyCol.find({"name": {"$regex" : "^a"}}, {"name" : 1})))
# Out:
# 71

# %% [markdown]
# As we can see regex is case sensitive. we can optionally use the param $options to make the search case insensitive

# %%
len(list(companyCol.find({"name": {"$regex" : "^a", '$options' : 'i'}}, {"name" : 1})))
# Out:
# 1312

# %%
#we can check for the word software in the overview field of documents 

len(list(companyCol.find({"overview": {"$regex" : "software", '$options' : 'i'}}, {"name" : 1, "overview":1})))
# Out:
# 2927

# %%
list(companyCol.find({"$and" : [{"overview": {"$regex" : "software", '$options' : 'i'}},
                                   {"overview": {"$regex" : "marketing", '$options' : 'i'}}]}, {"name" : 1, "overview":1}))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297dda'),
#   'name': 'iContact',
#   'overview': '<p>iContact is the largest private provider of email marketing and social media marketing software and services to small and mid-sized companies globally. It is based in Morrisville, NC. iContact makes it easy to create, send, and track email newsletters, surveys, autoresponders. iContact&#8217;s products include iContact, iContact Enterprise, iContact Agency, iContact for Salesforce, iContact Free Edition and Ettend.com. </p>\n\n<p>As a B Corporation, iContact utilizes the 4-1s Corporate Social Responsibility Model, donating 1% of employee time to community volunteering, 1% of payroll, 1% of equity, and 1% of product to its local and global community as part of its social mission. iContact works hard to maintain a fun, creative, energetic, challenging, and community-oriented company culture. </p>\n\n<p>iContact was founded in 2003 by Ryan Allis and Aaron Houghton in Chapel Hill, NC.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e2d'),
#   'name': 'Gumiyo',
#   'overview': '<p>Gumiyo enables publishers and businesses to connect with consumers on any device. The company&#8217;s cloud-hosted platform includes authoring tools that power more than 45,000 mobile sites, apps, and messaging programs for leading publishers, media companies, and software vendors worldwide. Integrating over 6,000 separate data sources including inventory systems, content management systems, CRM and ERP systems, Gumiyo&#8217;s platform enables its customers to build and distribute private label mobile solutions to over 150,000 small- and medium-sized businesses in a scalable and cost-effective way. </p>\n\n<p>Gumiyo operates across a number of industries, including traditional and digital publishers, broadcast media, automotive, real estate, local business and brand marketing.</p>\n\n<p>The company was founded in 2006 with corporate headquarters in Woodland Hills, CA.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3c'),
#   'name': 'Bazaarvoice',
#   'overview': '<p>Bazaarvoice is a Software as a Service (SaaS) company that turns social media into social commerce for the world&#8217;s best global brands by enabling authentic customer-powered marketing.</p>\n\n<p>We achieve that by first letting consumers create and share ratings, reviews, questions, answers, and stories about products and brands on client websites. We then syndicate that content across the Web and through the channel to reach shoppers wherever they are.</p>\n\n<p>This customer-generated content has a tremendously positive influence on purchase decisions. It is also rich with customer intelligence, which we analyze and provide to our clients so they can make real-time, information-based decisions that affect all aspects of their business — marketing, product R&amp;D, and operations.</p>\n\n<p>This strategy of putting customers at the center of your business helps you achieve measurable results across your entire enterprise.</p>\n\n<p>Brett Hurt, current Founder and CEO, and Brant Barton, Co-founder and current Chief Innovation Officer founded Bazaarvoice in 2005. Headquartered in Austin, the company has offices in Amsterdam, London, Munich, Paris, Stockholm, and Sydney.</p>\n\n<p>Visit www.bazaarvoice.com and www.bazaarvoice.com/blog</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e4b'),
#   'name': 'Jaxtr',
#   'overview': '<p><a href="http://www.jaxtr.com" title="Jaxtr" rel="nofollow">Jaxtr</a> first launched in March 2007 with a widget that enables users to receive calls from their friends through a VOIP connection and keep their personal phone numbers private.  </p>\n\n<p>In the past year, jaxtr has introduced a number of additional services in the attempt to monetize the company&#8217;s 10 million users:</p>\n\n<p>-Jaxtr helps users bypass expensive international phone charges by giving them free local numbers in the countries that they&#8217;re calling to and charges a nominal fee for connection and the ability to call from a mobile phone. As a marketing ploy, the company permits free calls to other members.\n-Jaxtr uses cafe jaxtr, a social network in which people call one another to discuss similar interests, and free global SMS to attract activity on its website and generate advertising revenue.</p>\n\n<p>The company maintains an advantage over competitors such as <a href="www.skype.com" title="Skype" rel="nofollow">Skype</a> by allowing customers to use any phone - mobile or landline - without the need to download software or maintain Internet access, and calling cards by eliminating the need to dial additional numbers and PIN codes. </p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297eb3'),
#   'name': 'Omnifuse',
#   'overview': '<p>Omnifuse is a social technology marketing company that also provides a social networking application framework called FUSION.  On the marketing side, Omnifuse offers consulting services for clients to improve the business development and publicity of their social networks.  The FUSION platform includes the core social networking features (like profile, photo, video, blogging, messaging, etc.), custom modules (like ratings, e-commerce, etc.), and an API used for integration.  Omnifuse can license this platform as a SaaS (Software as a Service), where it hosts and oversees all of the platform aspects, or can offer an enterprise-level customized platform.  Through its FUSION product and marketing services, Omnifuse offers solutions to increase other companies&#8217; social network traffic and ultimately boost company profitablity.  Omnifuse has partnered with companies including Microsoft, Google (Ad Sense), Brightcove, Adobe, and others.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297f8c'),
#   'name': 'Nemedia',
#   'overview': '<p>NEMedia is a full-service search engine marketing (SEM) company.  The company was started after Hamlet Batista started the company as a one man show. NEMedia recently released RankSense, a search optimization software suite.  RankSense offers a wizard-driven interface that claims to walk users through each step involved in making web pages &#8220;stand out in the eyes of both visitors and search engines.&#8221;</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675297fe3'),
#   'name': 'mEgo',
#   'overview': '<p>Los Angeles-based mEgo lets users create personalized avatars that carry their online profiles and can be integrated into users&#8217; blogs, social networks, websites, and IM clients. The online profiles display user-picked content like profile details, videos, photos, feeds, and widgets. When you update your profile on mEgo it updates your avatar profile on all your online properties. This will allow people to have one consistent, updated profile as they join, enhance and migrate from social network to social network. </p>\n\n<p>mEgo founder Ariel McNichol previously created popular software, games, and mobile products for Yahoo, AOL, Lucas Arts and Disney, and her co-founder Julia Johnston was a &#8220;lawyer and highly accomplished business strategist in the technology, media and telecommunication industries.&#8221; Ariel started working on prototypes for creating, managing and updating online profiles back in 1999. Their new online profile avatar mEgo&#8217;s revenue model consists of a blend of advertising, sponsorship, referral revenue and ecommerce.  In addition, mEgo will offer users the chance to allocate a portion of advertising revenue generated by their mEgos to a non-profit cause of their choice.  The company&#8217;s growth will come from viral marketing and promotion and distribution deals with social networks and other sites. </p>\n\n<p>Future plans include adding the following features: expanded widget support, enhanced visuals, non-avatar profile for professional networking, browser sidebar profile and a mobile mEgo. </p>\n\n<p>Similar competitors in the online profile space include <a href="http://www.crunchbase.com/company/profilebuilder" title="ProfileBuilder">ProfileBuilder</a>.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529800d'),
#   'name': 'Moz',
#   'overview': '<p>Moz provides analytics software to track all of a website&#8217;s inbound marketing efforts—search marketing, link building, social media, and brand mentions—on one platform. Moz Analytics tracks each effort with beautiful data visualizations, insights into competitors&#8217; data, and actionable recommendations to improve each effort&#8217;s performance. </p>\n\n<p>Dedicated to helping people do better marketing, Moz creates easy-to-use tools, tutorials, and educational resources for learning inbound marketing—and fosters the web’s most vibrant online marketing community. With offices in Seattle, WA and Portland, OR, Moz supports over 20,000 customers and 300,000 community members worldwide.</p>\n\n<p>The company received an A round of financing from Ignition Partners and Curious Office in September of 2007 to build their Linkscape web index.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298064'),
#   'name': 'Ubertor',
#   'overview': '<p>The business of Real Estate made easy.</p>\n\n<p>Ubertor provides fresh and easy to use software tailored towards Realtors and Real Estate.</p>\n\n<p>We help Realtors (and even small to medium sized businesses) around the globe power market their properties (and products) on our system. We pride ourselves in making the entire online marketing process for Realtors seamless and fun.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298094'),
#   'name': 'Alisoft',
#   'overview': '<p>Alisoft develops, markets and delivers Internet-based business management software targeting Small and Medium Enterprises (SMEs) in China. Founded by parent Alibaba Group, Alisoft is currently offering five different services: Customer relationship management (CRM), Inventory management, Sales force management, Financial tools,and Marketing information management. Alisoft is able to tailor its business software services and provide three editions: global trade, domestic China trade, and individual trade (consumer to consumer). Alisoft also develops the Aliwangwang instant messaging tool. Aliwangwang is used on the <a href="http://www.crunchbase.com/company/taobao" title="Taobao">Taobao</a>  online shopping marketplace.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752980c7'),
#   'name': 'BlackArrow',
#   'overview': '<p>BlackArrow is a leading worldwide provider of advanced advertising technology for New TV platforms. Reaching 30 million homes, BlackArrow’s advanced advertising software platform enables customers to increase revenues by delivering more timely and efficient sales and marketing messages, to extend TV business models and affiliate partnerships to new platforms, and to gain real-time reporting and measurement insights across multiple screens. BlackArrow is privately held, and backed by Cisco Systems (NASDAQ: CSCO), Comcast Ventures, Intel Capital (NASDAQ: INTC), Mayfield Fund, Google, Polaris Venture Partners and Time Warner Cable. The company has offices in New York City and San Jose, California. For more information, please visit www.BlackArrow.tv.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752980d4'),
#   'name': 'Optimost',
#   'overview': '<p>Optimost, LLC provides software and services for Website testing and optimization. It offers A/B and multivariable testing solutions for testing Websites, including landing pages, sign-in and shopping basket pages, graphics and text, Web forms, product pages, and email campaigns. The company also provides creative authoring tool, a content delivery platform that displays permutation of pages, including layout changes eliminating the need for internal creative resources. In addition, it offers consulting services, as well as managed solution services, including test plans to test variables and values; development of strategic testing and content targeting plans; experimental design services that allows clients to realize the potential of tests and verify findings; analysis of test results and data; and frequent strategic plan reviews to analyze testing results and recommend future strategies. Optimost, LLC serves e-commerce and retail, financial services, media and entertainment, automobile and transportation, technology and software, travel and leisure, education and non-profit, healthcare and pharmaceuticals, manufacturing, real estate, telecommunications, business-to-business services, agencies, consultants, and marketing services industries. </p>\n\n<p>The company was founded in 2001 and is based in San Jose, California. It has locations in New York, New York; London, the United Kingdom; and Tokyo, Japan. As of November 1, 2007, Optimost, LLC operates as a subsidiary of Interwoven Inc.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752980d3'),
#   'name': 'Interwoven',
#   'overview': '<p>Interwoven, Inc. provides content management software solutions.</p>\n\n<p>It offers its products and services through a direct sales force, and through relationships with technology vendors, professional service firms, systems integrators, digital/interactive marketing agencies, and other strategic partners in North America, the United Kingdom, and internationally.</p>\n\n<p>Interwoven has strategic partnerships with Microsoft Corporation and IBM. The company was founded in 1995 and is headquartered in San Jose, California. As of March 16, 2009, Interwoven Inc. operates as a subsidiary of Autonomy Corp. plc.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529813a'),
#   'name': 'HubSpot',
#   'overview': '<p>HubSpot is on a mission to replace the world&#8217;s annoying, interruptive marketing with marketing that people love. HubSpot software is the most powerful, tightly integrated and comprehensive marketing software available, putting personalized inbound marketing into the hands of any business.  Over 8,000 companies in 56 countries use our software to create lovable inbound marketing to attract, nurture and convert leads into an accelerating stream of new customers and revenue. HubSpot is also the developer of the popular website analysis tool, MarketingGrader.com, which has over 3 million users and grades upwards of 250,000 companies per month. HubSpot has been named one of the most promising, fastest growing companies by Inc, Forbes and Deloitte for the best possible reason: customer results. HubSpot has 400 employees, was founded in 2006 and is based in Cambridge, MA. For the love of marketing, find us at http://www.HubSpot.com.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298173'),
#   'name': 'Streamezzo',
#   'overview': '<p>Streamezzo S.A. develops media mobile products and solutions. Its solutions enable telecom operators, broadcasters, media companies, content providers, and service providers to design, develop, debug, and deploy services on cellular networks. The companyâ€™s products include Rich Media Software Suite, which comprise Rich Media Client that enables mobile users to access media services, such as interactive Mobile TV, widgets, portals, and multimedia services; Rich Media Server, an application server that enables to deploy media services; Workbench, an integrated multimedia authoring suite; Service Manager, a back-end solution that enables mobile administrators and marketers to manage and customize media mobile service; and Broadcast, which enables users to deliver mobile TV over broadcast networks. Its solutions comprise Interactive Mobile TV for interactive services; Music Jukebox for over-the-air music downloading; on-device portal for text, image, audio, and video combined information on a mobile portal; Event Microsite for mobile marketing; Dynamic User Interface, which enables to give customers direct access to specific services and applications; and online interactive communication solutions. The company also offers professional services. </p>\n\n<p>Streamezzo was founded in 2004 and is based in Paris, France.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529820d'),
#   'name': 'Adchemy',
#   'overview': '<p>Adchemy helps online brands scale ecommerce revenue acquisition with easy-to-use software that radically simplifies digital marketing campaigns and delivers unbelievably useful ads. Currently 8 out of the top 50 retailers on the IR500 us Adchemy software. For more information, please visit www.adchemy.com. </p>\n\n<p>The Adchemy platform automates and enforces best practices for keyword and PLA search campaigns, which leads to huge growth. On average, Adchemy software clients experience an improvement of 400+ percent more impressions, 150+ percent more clicks, at least 100 percent more revenue and 40+ percent higher margins, all while maintaining or exceeding target return on ad spend. </p>\n\n<p>Unlike other solutions designed for power users, Adchemy software is insanely easy to use. At the core of Adchemy’s software is the Adchemy IntentGraph that allows marketers and merchandisers to organize campaigns around their business language: products, not keywords. </p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298278'),
#   'name': 'Offermatica',
#   'overview': '<p>Offermatica Corporation develops and markets a Website content testing and performance optimization platform. The company develops software to test, measure, and optimize Internet marketing and advertising campaigns. It provides multivariate promotion testing, form and landing page optimization solutions for online advertisements, onsite merchandising, electronic mail campaigns, and pay-per-click listings. The company has strategic alliances with Coremetrics, DigitalGrit, Fathom Online, Outrider, and Bolt | Peters User Experience. Its clientele include Monster.com, ELOAN, Intuit, ESPN, Circuit City, Polo.com, Timberland, Sharper Image, Verisign, CNET, and Forbes.com. </p>\n\n<p>The company was formerly known as Fort Point Partners, Inc. The company was founded in 1996 and is headquartered in San Francisco, California with additional offices in New York, New York and London, United Kingdom. As of December 13, 2007, Offermatica Corporation operates as a subsidiary of Adobe Systems Inc.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752982f3'),
#   'name': 'QponDirect',
#   'overview': '<p><a href="http://www.qpondirect.com" title="QponDirect" rel="nofollow">QponDirect</a> is a Marketing Services and Software Development Company that provides a variety of digital services for manufactures, retailers, and consumers who use coupons. QponDirect provides an online marketing portal to manufacturers and retailers enabling them to produce, launch, manage and track consumer incentive programs using barcode encrypted digital coupons, incentives, and loyalty promotions. </p>\n\n<p>Consumers can use their cell phone or any internet enabled device (IED) as well as their free QCard,QCard both embedded with a unique, secure, QDID that will enable the consumer to access and redeem their coupons at the retailers point of sale or checkout counter. </p>\n\n<p>QponDirect generates income by charging a campaign setup fee to manufacturers (or retailers for loyalty programs) for the production, management,production and distribution services related to the individual digital campaign. QponDirect generated 90% of its revenue by charging a transaction fee only at the time the coupon, incentive, or loyalty promotion is redeemed by the consumer at the retailer checkout.</p>\n\n<p>Its basic service will be free for consumers. A &#8220;premium&#8221;\x9d consumer service scheduled to deploy in 2009 at $3.99 per month will be available for specialized offers from specialized retailers, and GPS services.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298313'),
#   'name': 'ShareMethods',
#   'overview': '<p>With ShareMethods, users can easily create, manage, and share documents on-demand. ShareMethods provides secure web access to document collaboration for sales, marketing, support, and product teams. </p>\n\n<p>ShareMethods delivers Software-as-a-Service  (SaaS) applications on a subscription basis for small, medium, and large companies.</p>\n\n<p>The company provides on-demand services to more than 200 companies on a global basis with users in more than 40 countries. Customers include BusinessWeek, HID Corp., Airspan Networks, CNET Channel, etc. </p>\n\n<p>ShareMethods is a co-founder of Open Simple Application Mashup (&#8220;OpenSAM&#8221; - www.opensam.org), an industry consortium working to improve interoperability across Office 2.0 applications.</p>\n\n<p>ShareMethods partners include salesforce.com, EchoSign, iNetWord, EditGrid, Preezo, Persony, Jotlet, Theikos, and Bluewolf. Products include ShareMethods, ShareNow for AppExchange, ShareOffice for AppExchange, and ShareDrive OnDemand.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298371'),
#   'name': 'IceBreaker',
#   'overview': '<p>IceBreaker connects people through mobile social networking software and services that are engaging and easy to use. With offices in Bellevue, Washington and Beijing, China, the company has an international network of vendors and partners who collectively serve our customers. </p>\n\n<p>IceBreaker is defining the next generation of mobile social networking communities. They enable partners to engage and monetize mobile data users across millions of daily page views and within multiple international markets. Their wireless social networking software and services are built on a robust, multi-platform technology and their executive team has deep consumer software development, wireless, marketing and entrepreneurial experience.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752983eb'),
#   'name': 'NAVIS',
#   'overview': '<p>NAVIS develops web-based software for the vacation rental management and independent resort markets. The software helps companies improve their ability to capture guest reservations, caller demographic data, guest preferences, and sales leads. NAVIS provides instant toll-free numbers for marketing campaigns, tracks marketing campaign calls and revenue results, measures internet keyword revenue, and provides data mining for targeted marketing.</p>\n\n<p>In addition to the software, NAVIS provides a 24x7 reservation call center that automatically captures after-hours reservation calls.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752983ea'),
#   'name': 'YaData',
#   'overview': '<p>YaData was purchased by Microsoft on February 27, 2008. It offers analytic software for marketers in the United States, including segment discovery and ranking, which combines statistical techniques for segment discovery. </p>\n\n<p>It also offers segment relationship management, which performs segment related activities, including segment discovery, analysis and research, marketing decision support, and tracking to monitor segment evolution. The company serves telecom, banking, insurance, credit card, and Web ad industries. YaData, Ltd. was founded in 2005 and is based in Tel Aviv, Israel.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298455'),
#   'name': 'Printfection',
#   'overview': '<p>Printfection is a turnkey merchandise marketing service to create awareness and loyalty. Using our tools you can easily launch a t-shirt giveaway or sell shirts to your fans. And we take care of everything - the online software, printing, fulfillment, and customer service.</p>\n\n<p>Additional Facts:\nHeadquartered in Denver, Colorado with additional production facilities in California and New York. Founded in 2004. Privately held, self-funded, and profitable. Over 5 million unique products for sale across 20,000+ online stores and giveaways.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298457'),
#   'name': 'Ifbyphone',
#   'overview': '<p>Ifbyphone, the leader in voice-based marketing automation (VBMA), connects, measures and optimizes sales and service calls for businesses and organizations. Ifbyphone’s VBMA solutions capture and manage phone leads and information that often slip through the cracks of traditional marketing automation and CRM software solutions.</p>\n\n<p>The Ifbyphone product suite is a set of software-as-a-service applications including call tracking, hosted IVR (interactive voice response), call routing, virtual call center and voice broadcasting. Organizations of all sizes in all industries use Ifbyphone, including marketing agencies, lead generation, e-commerce, direct response, financial services and insurance, health care, retail and logistics, and SaaS and technology. For more information, visit www.ifbyphone.com</p>\n\n<p>Our Core Values</p>\n\n<ul>\n<li>We will be the easiest company you have ever worked with, whether you are an employee, customer or investor</li>\n<li>We are committed to do the right thing for our employees, customers and investors</li>\n<li>We need to think fast, move fast and grow fast</li>\n<li>We need to be profitable in order to consistently serve our employees, customers and investors</li>\n</ul>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298479'),
#   'name': 'Aidmas Corporation',
#   'overview': '<p>Since 2004, Aidmas Corporation has delivered enterprise-level, campaign management Software-as-a-Service at an affordable price. By offering advanced online response and intelligent lead management, Aidmas empowers marketing professionals to better manage their business and improve their ROI. Organizations that have benefited from Aidmas deployments include Universitas 21 Global, Media Road Inc. and Harmony Mobile Networks. </p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298587'),
#   'name': 'WebVisible',
#   'overview': '<p>Based in Southern California, WebVisible is a Software as a Service (SaaS) company and leading name in local online advertising, known for being a true expert in bringing the Internet as an advertising and customer acquisition medium to small businesses around the world.</p>\n\n<p>Through direct sales and global partners in the Yellow Pages, newspaper, and online marketing industries, we offer our innovative online advertising products to small business customers.</p>\n\n<p>Our advertising products are powered by our award winning Geneva software platform - named 2008 Internet Product of the Year by the American Electronics Association - which buys advertising space across a variety of media, ensuring that our small business customers get the most effective, local, targeted advertising for their money.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752985b0'),
#   'name': 'Less Everything',
#   'overview': '<p>Less Everything is a privately held web application company based in Jacksonville, FL, United States. The company was co-founded in 2007 by President and CEO Steven Bristol and Vice President and COO Allan Branch. Services include web, graphic and UI design; customized software development; web applications; project management; code and performance reviews; Ruby on Rails tutoring; technical company interviews; search engine marketing; search engine optimization; and social media marketing.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752985c5'),
#   'name': 'Cvent',
#   'overview': '<p>Cvent is a leading cloud-based enterprise event management platform. Cvent offers software solutions to event planners for online event registration, venue selection, event management, mobile apps for events, e-mail marketing and web surveys; and to hotels for targeted advertising to event planners looking for suitable venues thus serving the entire event management value chain and enabling our clients around the world to manage hundreds of thousands of events and meetings. </p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298619'),
#   'name': 'Responsys',
#   'overview': '<p>Responsys (NASDAQ:MKTG) is a leading marketing cloud software and services company. Our mission is to enable the smartest marketing in the digital world. The most respected brands across the globe use the Responsys Interact Marketing Cloud to manage their digital relationships and deliver the right marketing to their customers across email, mobile, social, display and the web. Our customers gain competitive advantage through the automation, individualization, and coordination of cross-channel marketing interactions at massive scale. Founded in 1998, Responsys is headquartered in San Bruno, California and has offices throughout the world. For more information about Responsys, visit responsys.com.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529862d'),
#   'name': 'babbel',
#   'overview': '<p>Babbel is the smart learning system for languages. It is based on the latest technology, modern educational methods and a high fun-factor, making foreign language learning easy and enjoyable. </p>\n\n<p>The web and apps offer a interactive and in-depth way to learn a language.</p>\n\n<p>In stark contrast to other platforms that are quite regimented and continue to use traditional learning tools such as CD-ROMs, Babbel relies on a mixture of methods combining classic, interactive pronunciation, grammar and listening-comprehension exercises with authentic dialogues from everyday life. </p>\n\n<p>Numerous courses for beginners and continuing learners are available. Vocabulary, grammar and review, as well as original, thematically-organized lessons such as Idioms, the Digital World, Politics, Sports or Travel, allow you to learn whatever, however and wherever you want. </p>\n\n<p>Designed by a team of software experts and language-instruction professionals at the Berlin-based company Lesson Nine, the courses are always up to date. </p>\n\n<p>The success story began in 2007 when four friends from the music software industry noticed that it was not possible to learn languages on the internet. Originally, the idea had been to provide a tool for mixing music online. Lesson Nine founders Thomas Holl and Toine Diepstraten have many years of application development, IT management, community cultivation and interactive media experience. The other two founders, Lorenz Heine, was a co-founder and CFO of Native Instruments, and has extensive entrepreneurial experience in the software industry, while Markus Witte has online marketing and management experience, and a solid academic grounding in language, cultural theory and media. Head of Content Production Miriam Plieninger is an experienced expert and holds a Master&#8217;s degrees in language instruction.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529865c'),
#   'name': 'Infoblox',
#   'overview': '<p>Infoblox is the leading developer of network identity appliances that provide a scalable, secure way for enterprises to manage the critical network identity protocols—including DNS, DHCP, RADIUS and LDAP—that link business applications to the network infrastructure. Infoblox products increase network control while lowering TCO by delivering services that are more secure and scalable, easier to manage, and more reliable than &#8220;build-your-own&#8221;\x9d server-software solutions. The Infoblox distributed appliance approach also provides a secure, integrated platform for centralizing the management of identity data and services across the network. With sales and marketing presence in more than 30 countries, Infoblox has over 500 customers from a wide range of industries, many of them Fortune 500 companies.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298680'),
#   'name': 'ki work',
#   'overview': '<p>Ki Work - a better way of sourcing and operating online work</p>\n\n<p>Ki Work (the &#8220;Company&#8221;) is a search and operational utility for outsourcing and finding online work. Online work entails any work that can be performed remotely over the web by individuals using IT and telecoms. Online workers are independent professionals (freelancers) that wish to access the global market for work from wherever they are — to live local and work global. The Company enables experts in specific categories of expertise to mediate the global sourcing and operation of online work between buyers and sellers of professional online services. These cover over 400 different categories across most business functions including accounting, administration, consulting, customer service, legal, marketing, recruitment, sales, software, training and web development.</p>\n\n<p>Why Ki Work?</p>\n\n<p>Enabled by high speed communications, social networking, and online collaboration tools, around ten percent of all work can now be carried out entirely online. As yet however, there is no effective means of both sourcing online workers, and then managing them in distributed teams within an operational and organisational infrastructure. Ki Work provides a solution to this by (i) facilitating the sourcing of online work to help businesses to find and contract with the best workers at the lowest cost; and (ii) enabling expert intermediaries to project manage teams of online workers.  </p>\n\n<p>In an increasingly competitive global economy, companies require access to the best quality resources, at the lowest cost, and on demand. Ki Work uniquely addresses these needs through the creation of trusted online networks of buyers and professionals, facilitated by experts in specific categories of expertise. These experts act as &#8220;power networkers\x9d,&#8221; providing mentoring, pre-qualification and certification for professionals and buyers, building trust and co-ordinating projects involving multiple workers.  </p>\n\n<p>Ki Work launched in beta in July 2008. See</p>\n\n<p>Destination site: http://www.ki-work.com<br/>\nFacebook application: http://www.ki-work.com/bounce.html</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298696'),
#   'name': 'Marketo',
#   'overview': '<p>Marketo provides a complete <a href="http://www.marketo.com" title="marketing automation" rel="nofollow">marketing automation</a> software solution that is powerful and easy to use for fast-growing small companies and global enterprises alike.</p>\n\n<p>Built for marketers, by marketers, Marketo is designed to allow companies to launch their first campaign in days and scale to meet the needs of the most complex global enterprise. The solution delivers everything a marketer needs to deliver more sales leads with less work, including inbound marketing, <a href="http://www.marketo.com/global-enterprise/marketo-lead-management/" title="lead management" rel="nofollow">lead management</a>, social marketing, event management, instant CRM integration, sales dashboards, and marketing ROI reporting and analytics — all in one place.</p>\n\n<p>With proven technology, comprehensive services and expert guidance, Marketo helps thousands of companies around the world turn marketing from a cost center into a revenue driver.</p>\n\n<p>Marketo is the #1 Marketing Software Vendor on the INC 500 list and was recently named one of &#8220;America’s Most Promising Companies&#8221; by Forbes. In both 2011 and 2012 the company received the Best Marketing Solution award from CRM Magazine, and Salesforce.com customers have honored the company with the Best Marketing Automation Solution on the AppExchange for three years.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752986a0'),
#   'name': 'Attentio',
#   'overview': '<p>Attentio is a global company specialising in Social Media Monitoring. We have developed the award winning platform, the Attentio Brand Dashboard, enabling real-time monitoring and measurement of social media and online news. </p>\n\n<p>Industry specific</p>\n\n<p>With extensive expertise in the automotive, pharmaceutical, telecommunications, FMCG, and finance industries, Attentio is the European leader in Social Media information analytics. </p>\n\n<p>Multilingual coverage</p>\n\n<p>Our staff operates in 22 languages, including Arabic and Mandarin. With data sources covering the global blogosphere, we have the unique capability of analysing and correlating your relevant data with our SaaS (Software as a Service). </p>\n\n<p>Automated insights</p>\n\n<p>The Attentio Brand Dashboard lets you gain better understanding of the market, develop substantially improved marketing approaches, listen to and communicate directly with your customer and measure the RoI on your activities as deduced in the Social Media world.</p>\n\n<p>Working with the best</p>\n\n<p>We have worked with clients such as Microsoft, Skype, Toyota, Club Med, Johnson &amp; Johnson, Nokia, Intel, Hewlett Packard, and Buenavista International/Disney. We are also extensively used by Media agencies such as OMD, PHD Network, Emakina, Boondoggle, GfK, Edelman, LaComunidad, We are Social, Shiny Red, Isobar, Naked, Lateral and many more.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752986ad'),
#   'name': 'Plumtree Software',
#   'overview': '<p>Plumtree Software, Inc. engages in the development, marketing, and sale of a suite of software products for deploying Web applications. The company&#8217;s Enterprise Web Suite combines portal, content management, collaboration, integration, and search technologies. Its Corporate Portal provides the framework for applications, supports virtual community workspaces, and integrates them into a cohesive Web work environment. The Collaboration Server enables people to work together via the Web, supporting tasks, projects, communities, calendars, discussions, and document sharing with version control. The Content Server enables publication and management of Web content for portals and Web applications, with forms-based publishing, branding, templates, workflow, approvals, and content expiration. The Search Server indexes and searches all the documents, information, applications, communities, discussions, Web sites, and other content accessible through the portal. The Studio Server provides tools to portal managers to create forms-based portlets and application components without coding. The Web Services Integration technologies connect the portal to enterprise systems, repositories, and resources, with support for both .NET and Java integration. It also offers development and administration tools that are used to assemble, customize, deploy, and manage applications for users inside and outside the enterprise. In addition, Plumtree Software offers deployment and support services, consulting services, and training classes. It markets and sells its products through its direct sales force and through systems integrators, value-added resellers, and original equipment manufacturers in the United States, Canada, Europe, and Asia Pacific. Plumtree Software, Inc. was founded in 1996 and is headquartered in San Francisco, California. Plumtree Software Inc. operates as a subsidiary of Oracle Corp.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752986eb'),
#   'name': 'Topspin Media',
#   'overview': '<p>Founded in June 2007, Topspin is a leading-edge provider of marketing software and services that help artists and their partners build strong businesses and brands.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd675298752'),
#   'name': 'Marin Software',
#   'overview': '<p>Marin Software™ is a leading provider of online advertising management solutions, offering an integrated platform for managing search, display, and social marketing. The company provides solutions for advertisers and agencies of all sizes, enabling them to improve financial performance, save time, and make better decisions. Marin Enterprise, the company&#8217;s flagship product, addresses the needs of online marketers spending $100,000 per month and greater on biddable media.  Marin Professional delivers the same power and ease of use as Marin Enterprise, through an application designed for marketers spending less than $100,000 per month on paid search.  Headquartered in San Francisco, with offices worldwide, Marin&#8217;s technology powers marketing campaigns for over 1,500 customers managing more than $3.5 billion of annualized ad spend in more than 160 countries.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd67529876f'),
#   'name': 'Volusion',
#   'overview': '<p><a href="http://www.volusion.com" title="Volusion" rel="nofollow">Volusion</a> is a leader in ecommerce solutions for online businesses. Volusion provides shopping cart software for thousands of customers worldwide, including market leaders like Disney, Motorola, Chicago Tribune, 3M and Crutchfield. In 2009, over $2 billion in transactions were processed using the Volusion platform. Volusion is PCI certified and is listed on Visa&#8217;s approved provider list. </p>\n\n<p>Volusion&#8217;s shopping cart software includes features for product merchandising, site design, search engine optimization, online marketing and order processing. Other notable features include mCommerce, Social Store Builder, affiliate marketing and a loyalty rewards program. Volusion also offers additional services including domain names, credit card processing, fraud protection and more.</p>\n\n<p>All Volusion customers have unlimited free access to Volusion&#8217;s award-winning <a href="http://support.volusion.com" title="Out of this World Support" rel="nofollow">Out of this World Support</a>, available via phone, chat or ticket 24x7x365.</p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752987b2'),
#   'name': 'Palo Alto Software',
#   'overview': '<p>Palo Alto Software, Inc., was founded in Palo Alto (CA) in 1983 as Infoplan, a sole proprietorship. In 1988 it was incorporated in California as Palo Alto Software. Palo Alto Software moved to Oregon in 1992 and was subsequently merged into Palo Alto Software, an Oregon corporation.</p>\n\n<p>The business plan product evolved from extensive consulting in business planning for large and small companies. In 1984, Infoplan published a business plan template, which accompanied a book published by Oasis Press; and in 1988, the original version of Business Plan Toolkit was published.</p>\n\n<p>Since its release in 1995, Business Plan Pro has seen favorable reviews by numerous business and high-tech magazines and Internet sites. It is regularly on Amazon.com&#8217;s top 10 list of best-selling business software. Business Plan Pro has won many honors, and customized versions have been developed for corporations; regional version are available in Canada and the United Kingdom. The most recent versions, Business Plan Pro 11.0 and Business Plan Pro 11.0 Premier, were released in November 2007.</p>\n\n<p>Marketing Plan Pro was first released in 1996 and the current version, version 9.0 appearing in 2006. Advertising Plan Pro became available in November 2001. </p>\n\n<p>Email Center Pro is an email management software as a service product, and was officially launched in April, 2008.</p>\n\n<p>The newest product is LivePlan, business pitching, planning and financial tracking in the cloud. LivePlan launched in April, 2011.</p>\n\n<p>Palo Alto Software is also owns a content marketing site called Bplans.com. Bplans is focused on business planning and management topics, and is the largest business planning content site on the Web. </p>'},
#  {'_id': ObjectId('52cdef7c4bab8bd6752987d2'),
#   'name': 'TWT Interactive',
#   'overview': '<p>TWT Interactive offers marketing, sales and communication software.</p>'},
#  {'_id': ObjectId('52cdef7d4bab8bd6752988e3'),
#   'name': 'Vocus',
#   'overview': '<p>Vocus provides leading cloud-based marketing and public relations software and consulting services enabling companies to acquire and retain customers. The company offers products and services to help clients attract and engage prospects, capture and keep customers, and measure and improve marketing effectiveness. More than 17,000 annual subscription customers across a wide variety of industries use Vocus software. The company is headquartered in Beltsville, MD with offices in North America, Europe and Asia.</p>'},
#  {'_id': ObjectId('52cdef7d4bab8bd675298943'),
#   'name': 'Aprimo',
#   'overview': '<p>Aprimo delivers technology and insight that accelerates marketing productivity and the ability of marketing to document performance. Aprimo provides an Enterprise Marketing Management (EMM) product to leading marketing organizations around the world. Aprimo&#8217;s software is built on its visionary Enterprise Marketing Backbone which uses a services oriented architecture (SOA) that eliminates marketing as an island of automation. </p>\n\n<p>Aprimo is the global leader in delivering technology and insight that accelerates marketing productivity and the ability of marketing to document effective performance. Aprimo provides an Enterprise Marketing Management (EMM) product to leading marketing organizations around the world. Aprimo&#8217;s software is built on its visionary Enterprise Marketing Backbone™ which uses a services oriented architecture (SOA) that eliminates marketing as an island of automation. Aprimo Marketing Studio offers an integrated, interactive marketing solution that enables to develop, implement and manage every aspect of online marketing activities. Aprimo Marketing Studio includes traffic generation features missing from nearly all existing marketing automation products. Marketing Studio is designed as a true Software-as-a-Service system to tap underserved market and establish a leadership position in the emerging Online Marketing Management space aimed at mid-size and larger companies.</p>'},
#  {'_id': ObjectId('52cdef7d4bab8bd675298944'),
#   'name': 'Unica',
#   'overview': '<p>Unica Corporation provides enterprise marketing management software to financial services, insurance, retail, telecommunications, and travel and hospitality industries worldwide. The company&#8217;s software consists of seven modules: Campaign, Marketing Operations, Detect, Leads, NetInsight, CustomerInsight, and PredictiveInsight. The Campaign module allows marketing organizations to create, test, and execute customer interaction strategies across outbound and inbound touch points. The Marketing Operations module provides marketing operations and resource management capabilities that help marketers define, co-ordinate, monitor, control, and measure marketing program activities. The Detect module monitors high-volumes of transactional data to identify changes in behavior over time that signal a need to interact with a customer for sales or service opportunities. The Leads module enables marketers to manage the qualification, distribution, and maturation of leads between marketing activities and multiple sales channels. The NetInsight module collects, analyzes, and reports on Web site activity. The CustomerInsight module provides analytics for marketing performance management and cross-channel customer analysis through a visually intuitive interface. The PredictiveInsight module enables marketing organizations to automate the creation of predictive models to determine customer response propensities, recognize customers at risk of attrition, identify customer behaviors, analyze customer attributes and preferences, discover cross-selling opportunities, and forecast customer value. The company also provides implementation, training, consulting, maintenance, and technical support services. It offers its software through a direct sales force, as well as through alliances with marketing service providers, distributors, and systems integrators. The company was incorporated in 1992 and is headquartered in Waltham, Massachusetts.</p>'},
#  {'_id': ObjectId('52cdef7d4bab8bd6752989b9'),
#   'name': 'Snapbomb Blog Marketing',
#   'overview': '<p>Snapbomb is a blog marketing software platform that connects bloggers with advertisers, giving advertisers a simple way to use blogs to reach targeted end users with marketing messages, while giving bloggers a way to monetize their blogs.  </p>\n\n<p>Snapbomb automates the process of connecting advertisers with bloggers by giving blogs a value based on real statistics (traffic, ranks, feedback) and matching advertising campaigns with bloggers.</p>'},
#  {'_id': ObjectId('52cdef7d4bab8bd6752989a1'),
#   'name': 'Netscape',
# ...
#  {'_id': ObjectId('52cdef7f4bab8bd67529c3b9'),
#   'name': 'Broderbund Software',
#   'overview': '<p>As of August 31, 1998, Broderbund Software was acquired by Broderbund LLC. In June 1998, Broderbund Software, Inc. entered into a definitive merger agreement with TLC Merger Corp., a wholly owned subsidiary of The Learning Company, Inc. As of August 31, 1997, Broderbund Software, Inc. was engaged in the development, publishing, and marketing of a range of interactive personal productivity, entertainment, and education software for use in the home, school, and small business markets. The company sold its products through distributors, computer superstores, electronics stores, mass merchandisers, discount warehouse stores, office stores, software specialty retail chains, and educational dealers. In addition, Broderbund also sold its products directly to schools and to consumers through direct mail, telemarketing, and via the Internet. The company was founded in 1981.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c44a'),
#   'name': 'MentorMate',
#   'overview': '<p>MentorMate began as a mobile application development company, and quickly evolved into a Minnesota software development company. Over the past several years, MentorMate has evolved into a global IT solutions company. MentorMate has offices in the Twin Cities (Minneapolis and St. Paul, MN) as well as Sofia, Bulgaria.</p>\n\n<p>MentorMate provides:</p>\n\n<pre><code>* Custom software development\n* Web application development\n* Web marketing\n* Project management\n* Quality assurance\n* Staff augmentation\n* Consulting\n</code></pre>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c46a'),
#   'name': 'SalesInsight',
#   'overview': '<p>SalesInsight Services is a professional sales support and marketing consulting services company founded by experienced marketers that have a deep understanding of business challenges in the BPO and KPO industry providing high quality knowledge driven services in the area of marketing and sales and related business consulting services to organizations globally. \nOur approach and services have grown around our clientâ€™s requirements leading to high quality of services and client satisfaction. \nBeing a professional consulting firm we help clients in reducing sales cycle and cost of sales thus optimizing the sales team time and productivity and helping them in leveraging opportunities in new markets and geographies. Our unique blend of service offerings includes Market Research, Marketing Collateral Development, Template Development, Email Marketing, Direct Marketing, Telemarketing, and Sales Lead Generation.\nBased in India, SalesInsight provides international and domestic marketing reach to a gamut of industry verticals as software, information technology, healthcare, financial, engineering services and manufacturing, pharmaceuticals and business services. \nWe have a specialized support services for companies who wish to capitalize on India Inc brand and assist them to have a smooth India market entry</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c4e1'),
#   'name': 'UCWeb',
#   'overview': '<p>Mr. Yu Yongfu is the Chairman and CEO of UCWeb, responsible for the overall strategy planning and operations of the company. With extensive experience in strategic planning and venture capital, Mr. Yu holds a thorough understanding of the telecom, Internet, and new media industries in China. </p>\n\n<p>In early 2001, Yu Yongfu joined Legend Capital as one of the founders. He had been in charge of the investment in the telecom, new media, Internet and mobile Internet industries, and was appointed to the positions of investment manager and vice president.</p>\n\n<p>Yu has been awarded the 2009 Excellent Entrepreneur of China&#8217;s Software Industry, 2009 Top Ten Leaders of China&#8217;s New Media Industry, 2009 New Marketing Leader in China, 2009 Top Ten Innovators and Pioneers of Zhongguancun, 2008 Potential Pioneer of China, and 2008 Top Ten Innovators of New Media Industry, among other titles.</p>\n\n<p>Yu Yongfu graduated from International Business School of Nankai University in 1999 with a bachelor&#8217;s degree in economics.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c4e8'),
#   'name': 'TRA',
#   'overview': '<p>TRA, Inc. is a media and marketing research company whose proprietary patent pending platform, Media TRAnalyticsÂ®, cost effectively matches the ads that people actually receive with the products people actually buy, giving advertisers, agencies and media transparency, accountable measurement, media planning and improved return-on-investment for their advertising spend. TRA has 1.5 million households of TV set top box data from multiple software platforms, 54 million households of purchase data and the largest single source database ever â€“ 370,000 households.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c515'),
#   'name': 'iCentera',
#   'overview': '<p>iCentera is the leading provider of on-demand portal software for sales enablement. Our web-based software as a service (SaaS) increases sales revenue through a marketing, sales and customer messaging vehicle. Our hosted solutions quickly enable business users to create intranet sales portals, extranet channel partner portals and customer portals that deliver a consistent marketing voice across the entire enterprise and beyond.\niCentera provides easy to use solutions for &#8220;mortals&#8221; that incorporate automated content management, portal creation and built-in trend and behavior analytics through a cost-effective implementation that is running and available within days. With over 10,000 portals enabling sales and partners to sell more, iCentera is 360Â° Sales Enablementâ„¢.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c599'),
#   'name': 'Catapult Communications',
#   'overview': '<p>Catapult Communications Corporation engages in the design, development, manufacture, marketing, and support of software-based test systems for telecommunications industry. Its DCT2000 and MGTS products are digital communications test systems designed to enable equipment manufacturers and network operators to deliver complex digital telecommunications equipment and services. The companyâ€™s software and hardware assist customers in the design, integration, installation, and acceptance testing of a range of digital telecommunications equipment and services. Catapult Communicationsâ€™ products are used to perform various test functions, including design and feature verification, conformance testing, interoperability testing, and load and stress testing. The companyâ€™s customers include telecommunications equipment manufacturers and network operators. It markets its products through direct sales force, distributors, or sales agents worldwide. The company was founded in 1985 and is based in Mountain View, California. As of June 22, 2009, Catapult Communications Corporation operates as a subsidiary of Ixia.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c59e'),
#   'name': 'LocationLogic',
#   'overview': '<p>As of May 19, 2009, LocationLogic LLC was acquired by TeleCommunication Systems Inc. LocationLogic LLC provides platform software, applications frameworks, and professional services to wireless services providers. It offers LocationLogic software platform that provides the infrastructure, application services, content provisioning, and integration services, as well as the network connectivity, location-enabling services, and tools for deploying and maintaining location-based services, and offers the processing of transaction volumes, integration with existing network infrastructure, and an environment for developing new applications. The company also provides LocationLogic Insight, a software and an on-demand mobile resource management solution for small businesses; and LocationLogic Family Minder, a product suite for promoting communication within the family circle; a location gateway that manages application access to subscriber location information; a suite of geo-services for delivering location-based services; and professional services, such as installation, integration, and consulting services, as well as marketing programs, including marketing support services for activation, usage, and retention. Its LocationLogic software combines a wireless subscriber&#8217;s location with relevant information; refines and analyzes location information; manages data sets; provides a content management framework for developers to integrate and access spatial data sets; supports open standards that provide integration with existing applications; integrates with various network applications; provides an integration point to the carrier&#8217;s current location determination infrastructure; and supports application programming interface for building location-based services. </p>\n\n<p>The company is based in Overland Park, Kansas.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c5c6'),
#   'name': 'Incuity Software',
#   'overview': '<p>Incuity Software, Inc. is a privately-held Delaware corporation founded in 2004 in Mission Viejo, California. Although new as a corporation, the founders and staff of Incuity Software, formerly known as DataWorks Systems, have a long history in the design, development and marketing of industrial automation database and data analysis software products. </p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c5fa'),
#   'name': 'MSC Software',
#   'overview': '<p>MSC.Software Corporation and its subsidiaries engage in the development, marketing, and support of simulation software and related services. It offers engineering tools, such as MSC.Nastran, Patran, Adams, and Marc software to model and simulate the performance characteristics of various complex mechanical conditions. The company also provides multi-discipline (MD) solutions, such as MD Nastran and MD Adams that enable manufacturers to perform interoperable and multi-disciplinary analyses on products and assemblies in parallel. In addition, it offers SimEnterprise products, including SimXpert, SimManager Enterprise, and SimDesigner Enterprise that integrates simulation workflows and data within the extended enterprise. The company offers implementation services, including funded development, process consulting, and simulation methods development, as well as post deployment support, product maintenance, and customer support services. It serves customers in the aerospace, automotive, defense, heavy machinery, electronics, consumer products, biomedical, shipbuilding, and rail industries, as well as in universities and research centers. The company sells products and services through its sales force, as well as through third parties, including agents and value added resellers in North America, Latin America, Europe, the Middle East, Africa, and the Asia Pacific.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c601'),
#   'name': 'smartFOCUS',
#   'overview': '<p>smartFOCUS Group plc, through its subsidiaries, engages in the provision of computer consultancy and the development, marketing, and support of computer software in Europe, the United States, and Asia. The company offers smartSERVER, an integrated server platform that supports various communities of marketers who need access to detailed customer insight, from large and growing volumes of data; and smartMARKETER, an intelligent marketing application suite that provides digital, analysis, modeling, campaign management, and reporting products, serving the needs of marketers moving from broadcast to one to one customer relationship marketing. It also provides solutions, such as email marketing, digital marketing, analysis and modeling, campaign management, multi-channel marketing, single customer view, and software as a service that enable the delivery of personalized communications across various channels, such as print, email, mobile, and the Web. In addition, the company offers B2C marketing solutions for marketers to explore and develop optimized customer marketing strategies; B2B marketing solutions that provide single customer view, analysis, modeling, multi-channel campaign management, and measurement and reporting; news and media solutions, which enable marketers to leverage previously inaccessible data assets to produce revenue-generating analysis and insight; and marketing services partner (MSP) solutions that provide modular based marketing technology for MSPs. Further, it provides deployment services, including program and project management, as well as involves in the provision of learning and development, consultancy, and managed services. It serves market sectors, including financial services, media, telecoms, retail, utilities, travel, and marketing services partners.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c60c'),
#   'name': 'REApplications',
#   'overview': '<p>REApplications, Inc. provides on-demand or hosted commercial brokerage automation software solutions for the commercial real estate industry. It offers an operations suite that contains various modules for commission tracking, human resources management, analytics, and sign management. The company also provides a property customer relationship management (CRM) suite that contains various modules for project tracking, contacts, property inventory management, virtual earth maps, market statistics, and stacking plans. In addition, it offers a marketing suite that contains various modules for flash marketing, e-mail campaigns, brochure creation, and Website integration. The company was founded in 1999 and is based in San Diego, California. As of April 7, 2008, REApplications, Inc. operates as a subsidiary of LoopNet, Inc.</p>'},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c621'),
#   'name': 'Aleri Global Banking',
#   'overview': '<p>Aleri Global Banking engages in the design, development, and marketing of software products for banks in Europe, Americas, Asia, and the Middle East. Its products include ATLAS, a family of software solutions designed to support the wholesale transaction processing; Money Transfer, a software solution that addresses various aspects of the payment process, including routing mechanisms, and management of liquidity and collateral; and CLS Server, which provides various functions to support a CLS settlement member, as well as enable the member bank to provide CLS services to other institutions. The company also offers Global Banking Solutions, a range of financial software applications designed for the support of treasury, payments, and cash management activities; and FundTracer, a tracking system that provides banks and customers with information on the status of a payment. In addition, it provides training services, as well as consulting services in the areas of business process evaluation, project planning, implementation support, interface development, software management, end user support, and training. Aleri Global Banking was formerly known as mpct Solutions Corporation. The company was founded in 1981 and is based in Woking, United Kingdom. As of May 2008, Aleri Global Banking operates as a subsidiary of Wall Street Systems Delaware, Inc.</p>'}]
